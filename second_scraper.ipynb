# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import re
import time
import epicstore_api
from epicstore_api import EpicGamesStoreAPI, OfferData
import json

# %%
og_small = pd.read_csv("df_scraped.csv")
api = EpicGamesStoreAPI()
og_small
# Out:
#      Unnamed: 0  Number                         Name       Start         End  \
# 0             0     477                   The Bridge   3/14/2024   3/21/2024
# 1             1     476     Deus Ex: Mankind Divided   3/14/2024   3/21/2024
# 2             2     475                 Astro Duel 2    3/7/2024   3/14/2024
# 3             3     474  Aerial_Knight’s Never Yield   2/29/2024    3/7/2024
# 4             4     473       Super Meat Boy Forever   2/22/2024   2/29/2024
# ..          ...     ...                          ...         ...         ...
# 472         472       5                  Axiom Verge    2/7/2019   2/22/2019
# 473         473       4       The Jackbox Party Pack   1/24/2019    2/7/2019
# 474         474       3  What Remains of Edith Finch   1/11/2019   1/24/2019
# 475         475       2               Super Meat Boy  12/28/2018   1/10/2019
# 476         476       1                   Subnautica  12/12/2018  12/27/2018
#
#                                                   Link
# 0       https://store.epicgames.com/en-US/p/the-bridge
# 1    https://store.epicgames.com/en-US/p/deus-ex-ma...
# 2    https://store.epicgames.com/en-US/p/astro-duel...
# 3    https://store.epicgames.com/en-US/p/aerial-kni...
# 4    https://store.epicgames.com/en-US/p/super-meat...
# ..                                                 ...
# 472    https://store.epicgames.com/en-US/p/axiom-verge
# 473  https://store.epicgames.com/en-US/p/jackbox-pa...
# 474  https://store.epicgames.com/en-US/p/what-remai...
# 475  https://store.epicgames.com/en-US/p/super-meat...
# 476     https://store.epicgames.com/en-US/p/subnautica
#
# [477 rows x 6 columns]

# %%
def get_gamedata(gamename, searchsize = 5, less_strict = False):
    # takes a string gamename, searches for it (defaults to 5 search results), finds exact name/title match
    # returns dict with id, descr[iption], namespace, orig[inal]_price, fmt_orig_price (nicely formatted), and tags (list)
    dict = api.fetch_store_games(count = searchsize, keywords = gamename)
    match = None
    for element in dict["data"]["Catalog"]["searchStore"]["elements"]:
        # ideal case
        if element["title"] == gamename:
            match = element
            break

    # less strict matching mode, if enabled
    # generally want to change the api to match the og df name
    # will re-loop through returned results a second time looking for a match
    if less_strict == True:
        for element in dict["data"]["Catalog"]["searchStore"]["elements"]:
            # api space-hyphens become : like og df only, should never false positive
            if re.sub(r" -", ":", element["title"]) == gamename:
                match = element
                break
            # get rid of ALL nonalphanumerics, including special characters and whitespace
            # ALSO checks lowercase for case issues at same time
            if re.sub(r'[^a-zA-Z0-9]', '', element["title"]).lower() == re.sub(r'[^a-zA-Z0-9]', '', gamename).lower():
                match = element
                break
        # last resort, does ALL the dataframe version match the START of the api version? If so use the first result
        for element in dict["data"]["Catalog"]["searchStore"]["elements"]:
            if element["title"][:len(gamename)] == gamename:
                match = element
                break
            
            
    return_dict = {
    "id": match["id"],
    "descr": match["description"],
    "namespace": match["namespace"],
    "orig_price": match["price"]["totalPrice"]["originalPrice"],
    "fmt_orig_price": match["price"]["totalPrice"]["fmtPrice"]["originalPrice"],
    "tags": match["tags"]  # list but looks like individual dicts
    #TODO: possibly format the tags better
    #TODO: there might be one or two relevant pieces more to grab
    }
    return return_dict

# setting up a wrapped function to test other titles, eventually for the whole table, but to respect rate limits
def single_get(name, sleep_time = .5):
    time.sleep(sleep_time)
    #TODO: POTENTIALLY UNCOMMENT BELOW TEST OUTPUT PRINT STATEMENTS
    print("Attempting to grab data about", name)
    # No additional text = Success
    try:    
        done = get_gamedata(name, 5)
    #TODO: trying to think of possibility get_gamedata fails... maybe add a better fail return?
    except:
        try:
            # in this case, possibly the name wasn't within the first 5 results, so trying more and 
            print("RETRY RETRY:", name)
            done = get_better_gamedata(name, 40, True)
        except:
            # on a fail, I will return None and I will have to make this into an empty row later
            print("\tFAILED RETRY")
            done = None
    return done

# %%
# CAUTION: TAKES A LONG TIME TO RUN! OUTPUTS A LOT TOO!
# This goes through the entire table and uses the API for all almost 500 games
# could add optional argument sleep_time for other than .5 if I want to though
big_df = [single_get(a_game) for a_game in gdf["Name"]]  # pulls all strings from "Name" column in gdf, same order
big_df

# %%
# worried about data loss (long time to re-run), saving copies two ways to not overwrite by accident
# big_df_copy = big_df.copy()
# big_df_copy2 = big_df

# convert to dataframe and save to not re-run script (since with waits, takes a while)
# data = [d if d is not None else {} for d in big_df]
# adf = pd.DataFrame(data)
# adf.to_csv("~/Desktop/dshw/pypractice/df_api.csv", index = True)
# gdf.to_csv("~/Desktop/dshw/pypractice/df_scraped.csv", index = True)

# print(adf.columns, "\n", gdf.columns)
# # print(adf.head(5), gdf.head(5))
# joined = pd.merge(adf, gdf, left_index = True, right_index = True)
# print(joined.columns)
# print(joined.head(2))

# %%
# test bench and helper test functions off of saved CSV data

# loads the csv into "dff"
dff = pd.read_csv("df_joined.csv")

def titleresults(title, trycounts = 10):
    # returns TITLES ONLY for a default 10 search
    resdict = api.fetch_store_games(count = trycounts, keywords = title)
    match_found = 0
    for element in resdict["data"]["Catalog"]["searchStore"]["elements"]:
        if element["title"] == title:
            print("\n\nMATCH FOUND!!!!\n\n")
            match_found = 1
        print(element["title"])
    return match_found

def getname(index_num):
    # grabs the full name from index to save me typing
    return (dff.iloc[index_num]["Name"])

def jprint(thing):
    print(json.dumps(thing, indent = 2, default = str))

def testsuite(index_num):
    name = getname(index_num)
    print("-> Testing", name)
    print("A search returns the following:", titleresults(name))
    if titleresults(name) == 1:
        jprint(get_gamedata(name))
    elif titleresults(name, 100) == 1:
        jprint(get_gamedata(name))
    else:
        print("\n\nsadface") # somethign was supposed to go here

# failure mode: Doors - Paradox != Doors: Paradox
# get_gamedata("Doors: Paradox")
# jprint(api.fetch_store_games(count = 10, keywords = "Doors: Paradox"))
# also deus ex: mankind same exact (space then dash)
# SOLUTION: add text replacer? Not sure if this happens ALWAYS though.

# failure case: Love
# TWO causes for failure: too many results (doesn't appear until 60, too general)
# titleresults("Love")
# SOLUTION: ??? Do it manually?
# listed in scrape as Love but LOVE is different caps.
# SOLUTION: add text lowercase coercion?
# jprint(api.fetch_store_games(count = 70, keywords = "Love"))
# jprint(get_gamedata("Love"))
# titleresults("Love", 30)
# get_gamedata("Love")

# strange case: Destiny 2: Legacy Collection
# doesn't return in search at all, but also, 

# The Outer Worlds: Spacer's Choice Edition
# DOES return on search but gamedata doesn't return anything

# print(getname(22))

# testsuite(22)
jprint(api.fetch_store_games(count = 1, keywords = getname(2)))
astro = api.fetch_store_games(count = 1, keywords = getname(2))
jprint(astro["id"])
spacer = api.fetch_store_games(count = 10, keywords = getname(22))
print(spacer["id"])

# get_gamedata(getname(2))
# get_gamedata(getname(22))

# getname(12)
# titleresults(getname(12))
# get_gamedata(getname(12)) # it DOES get found but cannot retrieve
# jprint(api.fetch_store_games(count = 5, keywords = getname(12)))
# jprint(api.fetch_store_games(count = 5, keywords = getname(2)))
# Out:
# {
#   "data": {
#     "Catalog": {
#       "searchStore": {
#         "elements": [
#           {
#             "title": "Astro Duel 2",
#             "id": "bc38eac0277d41ec955690e25779cb53",
#             "namespace": "4a681a809a094e2c8dcc68353c68fed6",
#             "description": "Astro Duel 2 is a sci-fi combat game combining top-down space dog fights with up-close platforming action. Whether versus or co-op, battle through space and on foot at the same time! Strike within the fully-destructible arenas or just nuke \u2018em from orbit.",
#             "effectiveDate": "2024-03-07T16:00:00.000Z",
#             "keyImages": [
#               {
#                 "type": "OfferImageWide",
#                 "url": "https://cdn1.epicgames.com/spt-assets/3251b927449a471c883aab00c076d63c/astro-duel-2-ukpi8.png"
#               },
#               {
#                 "type": "OfferImageTall",
#                 "url": "https://cdn1.epicgames.com/spt-assets/3251b927449a471c883aab00c076d63c/astro-duel-2-1w3a4.png"
#               },
#               {
#                 "type": "Thumbnail",
#                 "url": "https://cdn1.epicgames.com/spt-assets/3251b927449a471c883aab00c076d63c/astro-duel-2-1w3a4.png"
#               }
#             ],
#             "seller": {
#               "id": "o-bkftz4vh5gcrv3aks6zkrtkulrgctm",
#               "name": "Wild Rooster"
#             },
#             "productSlug": null,
#             "urlSlug": "0218ebc2af7a45a6875cb57c893fce6a",
#             "url": null,
#             "tags": [
#               {
#                 "id": "1216"
#               },
#               {
#                 "id": "21894"
#               },
#               {
#                 "id": "19847"
#               },
#               {
#                 "id": "9547"
#               },
#               {
#                 "id": "9549"
#               },
#               {
#                 "id": "1264"
#               },
#               {
#                 "id": "1299"
#               },
#               {
#                 "id": "1110"
#               },
#               {
#                 "id": "22776"
#               },
#               {
#                 "id": "1370"
#               },
#               {
#                 "id": "1151"
#               },
#               {
#                 "id": "1183"
#               },
#               {
#                 "id": "10719"
#               }
#             ],
#             "items": [
#               {
#                 "id": "97664a972f654c4f85f6d008876d23b5",
#                 "namespace": "4a681a809a094e2c8dcc68353c68fed6"
#               }
#             ],
#             "customAttributes": [
#               {
#                 "key": "autoGeneratedPrice",
#                 "value": "false"
#               },
#               {
#                 "key": "isManuallySetViewableDate",
#                 "value": "true"
#               },
#               {
#                 "key": "isManuallySetPCReleaseDate",
#                 "value": "false"
#               },
#               {
#                 "key": "isBlockchainUsed",
#                 "value": "false"
#               }
#             ],
#             "categories": [
#               {
#                 "path": "games"
#               },
#               {
#                 "path": "games/edition"
#               },
#               {
#                 "path": "games/edition/base"
#               }
#             ],
#             "price": {
#               "totalPrice": {
#                 "discountPrice": 1999,
#                 "originalPrice": 1999,
#                 "voucherDiscount": 0,
#                 "discount": 0,
#                 "currencyCode": "USD",
#                 "currencyInfo": {
#                   "decimals": 2
#                 },
#                 "fmtPrice": {
#                   "originalPrice": "$19.99",
#                   "discountPrice": "$19.99",
#                   "intermediatePrice": "$19.99"
#                 }
#               },
#               "lineOffers": [
#                 {
#                   "appliedRules": []
#                 }
#               ]
#             }
#           }
#         ],
#         "paging": {
#           "count": 1,
#           "total": 2
#         }
#       }
#     }
#   },
#   "extensions": {}
# }
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 63
#      61 jprint(api.fetch_store_games(count = 1, keywords = getname(2)))
#      62 astro = api.fetch_store_games(count = 1, keywords = getname(2))
# ---> 63 jprint(astro["id"])
#      64 spacer = api.fetch_store_games(count = 10, keywords = getname(22))
#      65 print(spacer["id"])
#
# KeyError: 'id'

# %%
miss_inds = [1 ,3 ,8 ,10 ,12 ,22 ,28 ,35 ,42 ,66 ,67 ,68 ,
             72 ,74 ,76 ,84 ,85 ,86 ,90 ,92 ,98 ,100 ,102 ,
             103 ,106 ,109 ,112 ,119 ,121 ,127 ,128 ,130 ,133 ,
             135 ,138 ,144 ,146 ,149 ,152 ,153 ,156 ,158 ,159 ,
             160 ,166 ,171 ,173 ,189 ,193 ,195 ,200 ,202 ,205 ,
             211 ,215 ,217 ,220 ,227 ,230 ,231 ,232 ,233 ,235 ,
             236 ,239 ,250 ,252 ,258 ,270 ,271 ,274 ,275 ,277 ,
             282 ,287 ,291 ,295 ,298 ,306 ,313 ,315 ,316 ,327 ,
             330 ,332 ,334 ,335 ,337 ,339 ,340 ,342 ,343 ,348 ,
             349 ,360 ,363 ,364 ,368 ,373 ,382 ,383 ,393 ,403 ,
             404 ,416 ,426 ,431 ,437 ,438 ,439 ,440 ,441 ,442 ,444 ,445 ,462]
for i in miss_inds:
    print("\nORIGINAL:", getname(i))
    titleresults(getname(i)) 


# df entry: ":" vs api " -" with a space and hyphen
# df entry: lowercase vs api UPPERCASE variants
# df entry: no special chars, vs api R, TM, icons
    
# (LAST resort) use if all chars in df entry == same # of FIRST chars in api
#   more difficult: if 90% of chars match??
# alternate: IGNORE ALL non-space, nonalphanumeric ENTIRELY for matching!!
# Out:
# ORIGINAL: Deus Ex: Mankind Divided
# Deus Ex - Mankind Divided
# Deus Ex: Mankind Divided - Digital Deluxe Edition
#
# ORIGINAL: Aerial_Knight’s Never Yield
# Aerial_Knight's Never Yield
# Aerial_Knight's Never Yield - Deluxe Edition
# Aerial_Knight's We Never Yield
#
# ORIGINAL: Doors: Paradox
# Doors - Paradox
#
# ORIGINAL: Love
# 20 Minutes Till Dawn
# A Monster's Expedition
# A Rats Quest - The Way Back Home
# Acceptance
# Amber
# Anodyne 2 Game and Soundtrack Bundle
# At Eve's Wake Definitive Edition
# Bird of Paradise
# Black Hair Girl is Best Girl
# Blood on the Thames
#
# ORIGINAL: Marvel’s Guardians of the Galaxy
# Marvel's Guardians of the Galaxy
#
# ORIGINAL: The Outer Worlds: Spacer’s Choice Edition
# The Outer Worlds: Spacer's Choice Edition
#
# ORIGINAL: Destiny 2: Legacy Collection
#
# ORIGINAL: Earthlock
# EARTHLOCK
# Batman™: Arkham Knight
# Batman Arkham Knight
#
# ORIGINAL: Batman: Arkham City
# Batman Arkham Asylum Game of the Year Edition
# Batman™: Arkham City - Game of the Year Edition
# Batman Arkham City Game of the Year Edition
# LEGO® Batman™: The Videogame
#
# ORIGINAL: Batman: Arkham Asylum
# Batman™ Arkham Asylum Game of the Year Edition
# Batman Arkham Asylum Game of the Year Edition
# LEGO® Batman™: The Videogame
#
# ORIGINAL: LEGO Batman 3: Beyond Gotham
# LEGO® Batman™ 3: Beyond Gotham
# LEGO® Batman™ 3: Beyond Gotham
#
# ORIGINAL: LEGO Batman 2: DC Super Heroes
# LEGO® Batman™ 2: DC Super Heroes
# LEGO® Batman™ 2: DC Super Heroes
#
# ORIGINAL: LEGO Batman: The Videogame
# LEGO® Batman™ The Videogame
# LEGO® Batman™: The Videogame
#
# ORIGINAL: The End Is Nigh
# 20 Minutes Till Dawn
# Cyberpunk 2077
# Hell is Others
# The End is Nigh
# The End is Nigh
# The Isle Tide Hotel
# Them and Us
#
# ORIGINAL: Abzû
# ABZU
# The Pathless
#
# ORIGINAL: Kingdom: New Lands
# Kingdom New Lands
# Kingdom New Lands

# %%
def get_better_gamedata(gamename, searchsize = 5, less_strict = False):
    # takes a string gamename, searches for it (defaults to 5 search results), finds exact name/title match
    # returns dict with id, descr[iption], namespace, orig[inal]_price, fmt_orig_price (nicely formatted), and tags (list)
    dict = api.fetch_store_games(count = searchsize, keywords = gamename)
    match = None
    for element in dict["data"]["Catalog"]["searchStore"]["elements"]:
        # ideal case
        if element["title"] == gamename:
            match = element
            break

    # less strict matching mode, if enabled
    # generally want to change the api to match the og df name
    # will re-loop through returned results a second time looking for a match
    if less_strict == True:
        for element in dict["data"]["Catalog"]["searchStore"]["elements"]:
            # api space-hyphens become : like og df only, should never false positive
            if re.sub(r" -", ":", element["title"]) == gamename:
                match = element
                break
            # get rid of ALL nonalphanumerics, including special characters and whitespace
            # ALSO checks lowercase for case issues at same time
            if re.sub(r'[^a-zA-Z0-9]', '', element["title"]).lower() == re.sub(r'[^a-zA-Z0-9]', '', gamename).lower():
                match = element
                break
        # last resort, does ALL the dataframe version match the START of the api version? If so use the first result
        for element in dict["data"]["Catalog"]["searchStore"]["elements"]:
            if element["title"][:len(gamename)] == gamename:
                match = element
                break

    # NEEDED ONLY IF not wrapped in single_get (which handles errors)
    # if match == None:
    #     return {}
    
    return_dict = {
    "id": match["id"],
    "descr": match["description"],
    "namespace": match["namespace"],
    "orig_price": match["price"]["totalPrice"]["originalPrice"],
    "fmt_orig_price": match["price"]["totalPrice"]["fmtPrice"]["originalPrice"],
    "tags": match["tags"]  # list but looks like individual dicts
    #TODO: possibly format the tags better
    #TODO: there might be one or two relevant pieces more to grab
    }
    return return_dict

# %%
# for i in miss_inds:
#     time.sleep(.5)
#     print("\nORIGINAL:", getname(i))
#     get_better_gamedata(getname(i), 30, True) 
miss_names = [getname(i) for i in miss_inds]
# miss_df = [single_get(a_game) for a_game in gdf["Name"]]  # pulls all strings from "Name" column in gdf, same order
miss_df = [single_get(a_game) for a_game in miss_names]
miss_df
#
# ORIGINAL: Tiny Tina’s Assault on Dragon Keep
#
# ORIGINAL: Among the Sleep – Enhanced Edition
#
# ORIGINAL: Yoku’s Island Express
#
# ORIGINAL: Saints Row: The Third Remastered
#
# ORIGINAL: Train Sim World 2
#
# ORIGINAL: Hell Is Other Demons
#
# ORIGINAL: Control
#
# ORIGINAL: NBA 2K21
#
# ORIGINAL: The Lion’s Song
#
# ORIGINAL: World of Warships Exclusive Starter Pack
#
# ORIGINAL: Ken Follett’s The Pillars of the Earth
#
# ORIGINAL: The Fall
#
# ORIGINAL: Rage 2
#
# ORIGINAL: For the King
#
# ORIGINAL: Star Wars Battlefront II: Celebration Edition
#
# ORIGINAL: Darkest Dungeon
#
# ORIGINAL: Oddworld: New ‘n’ Tasty
#
# ORIGINAL: Pillars of Eternity: Definitive Edition
#
# ORIGINAL: Tyranny: Gold Edition
#
# ORIGINAL: Kingdom: New Lands
#
# ORIGINAL: Abzû
#
# ORIGINAL: RollerCoaster Tycoon 3: Complete Edition
#
# ORIGINAL: Stick It to the Man!
#
# ORIGINAL: Football Manager 2020
#
# ORIGINAL: Where the Water Tastes like Wine
#
# ORIGINAL: Shadowrun Hong Kong – Extended Edition
#
# ORIGINAL: Shadowrun: Dragonfall – Director’s Cut
#
# ORIGINAL: Hitman
#
# ORIGINAL: God’s Trigger
#
# ORIGINAL: Wilmot’s Warehouse
#
# ORIGINAL: 3 out of 10, EP 1
#
# ORIGINAL: Stranger Things 3: The Game
#
# ORIGINAL: Ark: Survival Evolved
#
# ORIGINAL: Samurai Shodown NeoGeo Collection
#
# ORIGINAL: Sid Meier’s Civilization VI
#
# ORIGINAL: For the King
#
# ORIGINAL: World War Z
#
# ORIGINAL: Tormentor X Punisher
#
# ORIGINAL: Assassin’s Creed Syndicate
#
# ORIGINAL: Darksiders II
#
# ORIGINAL: Darksiders
#
# ORIGINAL: Superhot
#
# ORIGINAL: Ruiner
#
# ORIGINAL: Observer
#
# ORIGINAL: Batman: Arkham Knight
#
# ORIGINAL: Batman: Arkham City
#
# ORIGINAL: Batman: Arkham Asylum
#
# ORIGINAL: LEGO Batman 3: Beyond Gotham
#
# ORIGINAL: LEGO Batman 2: DC Super Heroes
#
# ORIGINAL: LEGO Batman: The Videogame
#
# ORIGINAL: The End Is Nigh
#
# ORIGINAL: Abzû
#
# ORIGINAL: Kingdom: New Lands
# Attempting to grab data about Deus Ex: Mankind Divided
# RETRY RETRY: Deus Ex: Mankind Divided
# Attempting to grab data about Aerial_Knight’s Never Yield
# RETRY RETRY: Aerial_Knight’s Never Yield
# Attempting to grab data about Doors: Paradox
# RETRY RETRY: Doors: Paradox
# Attempting to grab data about Love
# RETRY RETRY: Love
# Attempting to grab data about Marvel’s Guardians of the Galaxy
# RETRY RETRY: Marvel’s Guardians of the Galaxy
# Attempting to grab data about The Outer Worlds: Spacer’s Choice Edition
# RETRY RETRY: The Outer Worlds: Spacer’s Choice Edition
# Attempting to grab data about Destiny 2: Legacy Collection
# RETRY RETRY: Destiny 2: Legacy Collection
# Attempting to grab data about Earthlock
# RETRY RETRY: Earthlock
# Attempting to grab data about Q.U.B.E. 2 Season Pass
# RETRY RETRY: Q.U.B.E. 2 Season Pass
# Attempting to grab data about Grime
# RETRY RETRY: Grime
# Attempting to grab data about The Dungeon of Naheulbeuk: The Amulet of Chaos
# RETRY RETRY: The Dungeon of Naheulbeuk: The Amulet of Chaos
# Attempting to grab data about theHunter: Call of the Wild
# RETRY RETRY: theHunter: Call of the Wild
# Attempting to grab data about Payday 2
# RETRY RETRY: Payday 2
# Attempting to grab data about Fallout: New Vegas Ultimate Edition
# RETRY RETRY: Fallout: New Vegas Ultimate Edition
# Attempting to grab data about The Sims 4 The Daring Lifestyle Bundle
# RETRY RETRY: The Sims 4 The Daring Lifestyle Bundle
# Attempting to grab data about Second Extinction
# RETRY RETRY: Second Extinction
# Attempting to grab data about Mordhau
# RETRY RETRY: Mordhau
# Attempting to grab data about Dying Light: The Following – Enhanced Edition
# RETRY RETRY: Dying Light: The Following – Enhanced Edition
# Attempting to grab data about World of Warships – Starter Pack: Ishizuchi
# RETRY RETRY: World of Warships – Starter Pack: Ishizuchi
# Attempting to grab data about Warhammer 40,000: Gladius – Relics of War
# RETRY RETRY: Warhammer 40,000: Gladius – Relics of War
# Attempting to grab data about Dishonored: Death of the Outsider
# RETRY RETRY: Dishonored: Death of the Outsider
# Attempting to grab data about Hell Is Others
# RETRY RETRY: Hell Is Others
# Attempting to grab data about Epistory: Typing Chronicles
# RETRY RETRY: Epistory: Typing Chronicles
# Attempting to grab data about Gamedec: Definitive Edition
# RETRY RETRY: Gamedec: Definitive Edition
# Attempting to grab data about Shadow Tactics: Aiko’s Choice
# RETRY RETRY: Shadow Tactics: Aiko’s Choice
# Attempting to grab data about Dishonored: Definitive Edition
# RETRY RETRY: Dishonored: Definitive Edition
# Attempting to grab data about F.I.S.T.: Forged in Shadow Torch
# RETRY RETRY: F.I.S.T.: Forged in Shadow Torch
# Attempting to grab data about LEGO Builder’s Journey
# RETRY RETRY: LEGO Builder’s Journey
# Attempting to grab data about Them’s Fightin’ Herds
# RETRY RETRY: Them’s Fightin’ Herds
# Attempting to grab data about Saints Row IV: Re-Elected
# RETRY RETRY: Saints Row IV: Re-Elected
# Attempting to grab data about RPG in a Box
# RETRY RETRY: RPG in a Box
# Attempting to grab data about Star Wars: Squadrons
# RETRY RETRY: Star Wars: Squadrons
# Attempting to grab data about Epic Cheerleader Pack
# RETRY RETRY: Epic Cheerleader Pack
# Attempting to grab data about Alba: A Wildlife Adventure
# RETRY RETRY: Alba: A Wildlife Adventure
# Attempting to grab data about Warhammer 40,000: Mechanicus
# RETRY RETRY: Warhammer 40,000: Mechanicus
# Attempting to grab data about Slain: Back from Hell
# RETRY RETRY: Slain: Back from Hell
# Attempting to grab data about The Drone Racing League
# RETRY RETRY: The Drone Racing League
# Attempting to grab data about Ark: Survival Evolved
# RETRY RETRY: Ark: Survival Evolved
# Attempting to grab data about Realm Royale Reforged – Epic Launch Bundle
# RETRY RETRY: Realm Royale Reforged – Epic Launch Bundle
# Attempting to grab data about Hundred Days – Winemaking Simulator
# RETRY RETRY: Hundred Days – Winemaking Simulator
# Attempting to grab data about Knockout City
# RETRY RETRY: Knockout City
# Attempting to grab data about Destiny 2: Bungie 30th Anniversary Pack
# RETRY RETRY: Destiny 2: Bungie 30th Anniversary Pack
# Attempting to grab data about Rumbleverse – Boom Boxer Content Pack
# RETRY RETRY: Rumbleverse – Boom Boxer Content Pack
# Attempting to grab data about Doom 64
# RETRY RETRY: Doom 64
# Attempting to grab data about Wonder Boy: The Dragon’s Trap
# RETRY RETRY: Wonder Boy: The Dragon’s Trap
# Attempting to grab data about Geneforge 1 – Mutagen
# RETRY RETRY: Geneforge 1 – Mutagen
# Attempting to grab data about A Game of Thrones: The Board Game Digital Edition
# RETRY RETRY: A Game of Thrones: The Board Game Digital Edition
# Attempting to grab data about XCOM 2
# RETRY RETRY: XCOM 2
# Attempting to grab data about Total War: Warhammer
# RETRY RETRY: Total War: Warhammer
# Attempting to grab data about Demon’s Tilt
# RETRY RETRY: Demon’s Tilt
# Attempting to grab data about Dauntless – Epic Slayer Kit
# RETRY RETRY: Dauntless – Epic Slayer Kit
# Attempting to grab data about Brothers: A Tale of Two Sons
# RETRY RETRY: Brothers: A Tale of Two Sons
# Attempting to grab data about Daemon X Machina
# RETRY RETRY: Daemon X Machina
# Attempting to grab data about Tomb Raider Game of the Year Edition
# RETRY RETRY: Tomb Raider Game of the Year Edition
# Attempting to grab data about Control
# RETRY RETRY: Control
# Attempting to grab data about Pathfinder: Kingmaker
# RETRY RETRY: Pathfinder: Kingmaker
# Attempting to grab data about Second Extinction
# RETRY RETRY: Second Extinction
# Attempting to grab data about Godfall Challenger Edition
# RETRY RETRY: Godfall Challenger Edition
# Attempting to grab data about Antstream – Epic Welcome Pack
# RETRY RETRY: Antstream – Epic Welcome Pack
# Attempting to grab data about theHunter: Call of the Wild
# RETRY RETRY: theHunter: Call of the Wild
# Attempting to grab data about Guild of Dungeoneering
# RETRY RETRY: Guild of Dungeoneering
# Attempting to grab data about Kid A Mnesia Exhibition
# RETRY RETRY: Kid A Mnesia Exhibition
# Attempting to grab data about Rogue Company Season Four Epic Pack
# RETRY RETRY: Rogue Company Season Four Epic Pack
# Attempting to grab data about Tiny Tina’s Assault on Dragon Keep
# RETRY RETRY: Tiny Tina’s Assault on Dragon Keep
# Attempting to grab data about Among the Sleep – Enhanced Edition
# RETRY RETRY: Among the Sleep – Enhanced Edition
# Attempting to grab data about Yoku’s Island Express
# RETRY RETRY: Yoku’s Island Express
# Attempting to grab data about Saints Row: The Third Remastered
# RETRY RETRY: Saints Row: The Third Remastered
# Attempting to grab data about Train Sim World 2
# RETRY RETRY: Train Sim World 2
# Attempting to grab data about Hell Is Other Demons
# RETRY RETRY: Hell Is Other Demons
# Attempting to grab data about Control
# RETRY RETRY: Control
# Attempting to grab data about NBA 2K21
# RETRY RETRY: NBA 2K21
# Attempting to grab data about The Lion’s Song
# RETRY RETRY: The Lion’s Song
# Attempting to grab data about World of Warships Exclusive Starter Pack
# RETRY RETRY: World of Warships Exclusive Starter Pack
# Attempting to grab data about Ken Follett’s The Pillars of the Earth
# RETRY RETRY: Ken Follett’s The Pillars of the Earth
# Attempting to grab data about The Fall
# RETRY RETRY: The Fall
# Attempting to grab data about Rage 2
# RETRY RETRY: Rage 2
# Attempting to grab data about For the King
# RETRY RETRY: For the King
# Attempting to grab data about Star Wars Battlefront II: Celebration Edition
# RETRY RETRY: Star Wars Battlefront II: Celebration Edition
# Attempting to grab data about Darkest Dungeon
# RETRY RETRY: Darkest Dungeon
# Attempting to grab data about Oddworld: New ‘n’ Tasty
# RETRY RETRY: Oddworld: New ‘n’ Tasty
# Attempting to grab data about Pillars of Eternity: Definitive Edition
# RETRY RETRY: Pillars of Eternity: Definitive Edition
# Attempting to grab data about Tyranny: Gold Edition
# RETRY RETRY: Tyranny: Gold Edition
# Attempting to grab data about Kingdom: New Lands
# RETRY RETRY: Kingdom: New Lands
# Attempting to grab data about Abzû
# RETRY RETRY: Abzû
# Attempting to grab data about RollerCoaster Tycoon 3: Complete Edition
# RETRY RETRY: RollerCoaster Tycoon 3: Complete Edition
# Attempting to grab data about Stick It to the Man!
# RETRY RETRY: Stick It to the Man!
# Attempting to grab data about Football Manager 2020
# RETRY RETRY: Football Manager 2020
# Attempting to grab data about Where the Water Tastes like Wine
# RETRY RETRY: Where the Water Tastes like Wine
# Attempting to grab data about Shadowrun Hong Kong – Extended Edition
# RETRY RETRY: Shadowrun Hong Kong – Extended Edition
# Attempting to grab data about Shadowrun: Dragonfall – Director’s Cut
# RETRY RETRY: Shadowrun: Dragonfall – Director’s Cut
# Attempting to grab data about Hitman
# RETRY RETRY: Hitman
# Attempting to grab data about God’s Trigger
# RETRY RETRY: God’s Trigger
# Attempting to grab data about Wilmot’s Warehouse
# RETRY RETRY: Wilmot’s Warehouse
# Attempting to grab data about 3 out of 10, EP 1
# RETRY RETRY: 3 out of 10, EP 1
# Attempting to grab data about Stranger Things 3: The Game
# RETRY RETRY: Stranger Things 3: The Game
# Attempting to grab data about Ark: Survival Evolved
# RETRY RETRY: Ark: Survival Evolved
# Attempting to grab data about Samurai Shodown NeoGeo Collection
# RETRY RETRY: Samurai Shodown NeoGeo Collection
# Attempting to grab data about Sid Meier’s Civilization VI
# RETRY RETRY: Sid Meier’s Civilization VI
# Attempting to grab data about For the King
# RETRY RETRY: For the King
# Attempting to grab data about World War Z
# RETRY RETRY: World War Z
# Attempting to grab data about Tormentor X Punisher
# RETRY RETRY: Tormentor X Punisher
# Attempting to grab data about Assassin’s Creed Syndicate
# RETRY RETRY: Assassin’s Creed Syndicate
# Attempting to grab data about Darksiders II
# RETRY RETRY: Darksiders II
# Attempting to grab data about Darksiders
# RETRY RETRY: Darksiders
# Attempting to grab data about Superhot
# RETRY RETRY: Superhot
# Attempting to grab data about Ruiner
# RETRY RETRY: Ruiner
# Attempting to grab data about Observer
# RETRY RETRY: Observer
# Attempting to grab data about Batman: Arkham Knight
# RETRY RETRY: Batman: Arkham Knight
# Attempting to grab data about Batman: Arkham City
# RETRY RETRY: Batman: Arkham City
# Attempting to grab data about Batman: Arkham Asylum
# RETRY RETRY: Batman: Arkham Asylum
# Attempting to grab data about LEGO Batman 3: Beyond Gotham
# RETRY RETRY: LEGO Batman 3: Beyond Gotham
# Attempting to grab data about LEGO Batman 2: DC Super Heroes
# RETRY RETRY: LEGO Batman 2: DC Super Heroes
# Attempting to grab data about LEGO Batman: The Videogame
# RETRY RETRY: LEGO Batman: The Videogame
# Attempting to grab data about The End Is Nigh
# RETRY RETRY: The End Is Nigh
# Attempting to grab data about Abzû
# RETRY RETRY: Abzû
# Attempting to grab data about Kingdom: New Lands
# RETRY RETRY: Kingdom: New Lands
# [{'id': 'a74220fd07e34b01987fb801433fb2e6',
#   'descr': 'Secure the Digital Deluxe edition now to gain access to the Season Pass, an Extra In-Game Mission and more!',
#   'namespace': '5c5b2b01c8ce475d86cdd2c76fd11f7b',
#   'orig_price': 4499,
#   'fmt_orig_price': '$44.99',
#   'tags': [{'id': '1336'}, {'id': '1370'}, {'id': '9547'}, {'id': '1084'}]},
#  {'id': '2fecb1793ce446408cd869611400a797',
#   'descr': "Take the role of Wally. A mysterious character that has recovered what was taken from him. Hopefully, you're fast enough to outrun your enemies.   Run, Jump, Slide or Dash for acrobatic variants leading to dope combinations and avoid the challenges that await.",
#   'namespace': '2ed7ed64d8604265924b85bbd5670220',
#   'orig_price': 1199,
#   'fmt_orig_price': '$11.99',
#   'tags': [{'id': '1216'},
#    {'id': '21894'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1263'}]},
#  {'id': 'b8dee54bce824477bc0b7cb298f9f9a9',
#   'descr': 'A relaxing puzzle escape game! Make your way through a variety of hand-crafted 3D dioramas, look for useful objects, find hidden clues, and solve fun puzzles! Unravel this mysterious adventure about chaos, order, and the surreal.',
#   'namespace': '88c17fed155e43068c338d33d1bcd481',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1296'},
#    {'id': '1298'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'}]},
#  {},
#  {'id': 'a2fc9e21ab4e416680c2b9597b7f6eaf',
#   'descr': 'You are Star-Lord. The fate of the galaxy and the Guardians is in your hands. Time to show the universe what you’re made of. You got this. Probably.',
#   'namespace': '2a09fb19b47f46dfb11ebd382f132a8f',
#   'orig_price': 5999,
#   'fmt_orig_price': '$59.99',
#   'tags': [{'id': '1216'},
#    {'id': '21122'},
#    {'id': '1188'},
#    {'id': '21894'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '15375'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1336'},
#    {'id': '1370'},
#    {'id': '1117'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': '0769596f15a445b7a5ad3f8d7c7730e2',
#   'descr': 'The Outer Worlds: Spacer’s Choice Edition is the ultimate way to play the award-winning RPG from Obsidian Entertainment and Private Division. Including the base game and all DLC, this remastered masterpiece is the absolute best version of The Outer Worlds.',
#   'namespace': 'dc61166eea95474e912953b163791d42',
#   'orig_price': 5999,
#   'fmt_orig_price': '$59.99',
#   'tags': [{'id': '1216'},
#    {'id': '21122'},
#    {'id': '1188'},
#    {'id': '21894'},
#    {'id': '21127'},
#    {'id': '21130'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '15375'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1367'},
#    {'id': '1210'},
#    {'id': '1370'},
#    {'id': '21147'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {},
#  {'id': '54412e4f88824cb2a3f1dbb604b59c16',
#   'descr': 'Don’t let the cute cartoonish art style fool you. This game is challenging. True fans of the JRPG genre will love it, casual players may want to look elsewhere. Invest the time, and EARTHLOCK will reward you with a depth in gameplay that will test the most strategic of players.',
#   'namespace': '5c82c05d2978489090d30c05e17e6e12',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1287'},
#    {'id': '1367'},
#    {'id': '1370'},
#    {'id': '1386'},
#    {'id': '9547'},
#    {'id': '35244'},
#    {'id': '9549'}]},
#  {},
#  {'id': '3f468b7977d0416a9a36af16f384c516',
#   'descr': 'GRIME is a fast, unforgiving Action-Adventure RPG in which you crush your foes with living weapons that mutate form and function, and then consume their remains with a black hole to strengthen your vessel as you break apart a world of anatomical intrigue.',
#   'namespace': '3bb4afc31dd241c787bad056e9b8dbf9',
#   'orig_price': 2499,
#   'fmt_orig_price': '$24.99',
#   'tags': [{'id': '21894'},
#    {'id': '19847'},
#    {'id': '21127'},
#    {'id': '21129'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '15375'},
#    {'id': '21137'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '21149'},
#    {'id': '1151'},
#    {'id': '1247'}]},
#  {},
#  {'id': '7b0d120a875547e9bec70192ddcc96e2',
#   'descr': 'Experience an atmospheric hunting game like no other in this realistic and visually breathtaking open world. Immerse yourself in the atmospheric single player campaign, or share the ultimate hunting experience with friends.',
#   'namespace': 'c7f9346e3db148fca6dd63e9dd8451bd',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1188'},
#    {'id': '9547'},
#    {'id': '1294'},
#    {'id': '1264'},
#    {'id': '1393'},
#    {'id': '21138'},
#    {'id': '1203'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '21146'},
#    {'id': '1307'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': 'c5249beb4ffe4cddb8a21e422f93e59a',
#   'descr': 'Description is not set',
#   'namespace': '3b661fd6a9724ac7b6ac6d10d0572511',
#   'orig_price': 1099,
#   'fmt_orig_price': '$10.99',
#   'tags': [{'id': '1216'},
#    {'id': '1264'},
#    {'id': '29088'},
#    {'id': '21894'},
#    {'id': '19847'},
#    {'id': '22776'},
#    {'id': '1210'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1294'}]},
#  {'id': '08834851d4a54f48b485e97caab98012',
#   'descr': 'Feel the Heat in New Vegas! Not even nuclear fallout could slow the hustle of Sin City. Explore the vast expanses of the desert wastelands and see the Great Southwest as could only be imagined in Fallout.',
#   'namespace': '3428aaab2c674c98b3acb789dcfaa548',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1367'},
#    {'id': '19847'},
#    {'id': '1210'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '35244'}]},
#  {},
#  {},
#  {'id': '7f89db821ab1441981adb4daf31c06db',
#   'descr': 'MORDHAU is a multiplayer medieval slasher. Create your mercenary and fight in brutal battles where you will experience fast paced combat, castle sieges, cavalry charges, and more.',
#   'namespace': '2bda08f9230144a19e98373cc4a6ac2d',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1216'},
#    {'id': '1264'},
#    {'id': '21122'},
#    {'id': '21138'},
#    {'id': '1203'},
#    {'id': '1299'},
#    {'id': '21139'},
#    {'id': '21141'},
#    {'id': '19847'},
#    {'id': '21129'},
#    {'id': '9547'}]},
#  {},
#  {},
#  {'id': '0fffb527a35441b08505c018dc1812bd',
#   'descr': 'Warhammer 40,000: Gladius – Relics of War is the first turn-based 4X strategy game set in the Warhammer 40,000 universe. Four factions will engage in a brutal war for dominance over the planet’s resources.',
#   'namespace': '0d89655f53884b09b241b60c07e684af',
#   'orig_price': 3999,
#   'fmt_orig_price': '$39.99',
#   'tags': [{'id': '21122'},
#    {'id': '1188'},
#    {'id': '21894'},
#    {'id': '1386'},
#    {'id': '9547'},
#    {'id': '1166'},
#    {'id': '15375'},
#    {'id': '1264'},
#    {'id': '21138'},
#    {'id': '1203'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '1115'},
#    {'id': '21149'}]},
#  {'id': 'faf518d367de4306a911ce211c8e47e4',
#   'descr': "Take on the role of Billie Lurk as she reunites with her old mentor, Daud, to undertake the greatest assassination ever conceived: killing the Outsider, a god-like figure whom they both see as instrumental to some of the Empire's most dishonorable moments. ",
#   'namespace': '87c84bc5f43d4fe69ad8f3ccde0594b0',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1216'},
#    {'id': '21122'},
#    {'id': '1188'},
#    {'id': '21894'},
#    {'id': '21127'},
#    {'id': '9547'},
#    {'id': '15375'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '1084'},
#    {'id': '1117'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': 'c1735ab5600741489a3ed30ed18c8b2f',
#   'descr': 'Hell is Others is an extraction horror PVPVE top-down shooter. Outside the safety of your apartment lies the noir hellscape of Century City. A city of endless night that straddles the line between reality and insanity. Explore, hunt and loot in a place where blood is currency.',
#   'namespace': 'bd75186521ab40b5840774b78bb287e3',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '29088'},
#    {'id': '21121'},
#    {'id': '21125'},
#    {'id': '21894'},
#    {'id': '19847'},
#    {'id': '21129'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '21137'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1080'},
#    {'id': '22776'},
#    {'id': '1370'},
#    {'id': '1083'},
#    {'id': '21149'}]},
#  {'id': '63352c1c0eed4ab9a640dafee08eff54',
#   'descr': 'Epistory immerses you in an atmospheric game where you play a girl riding a giant fox who fights an insectile corruption from an origami world. As you progress and explore this world, the story literally unfolds and the mysteries of the magic power of the words are revealed.',
#   'namespace': '6a6d54e5b4ef4fb0b3dad1d02a320376',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1381'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '15375'}]},
#  {'id': '61d13d6fe0c84016a8bacd6fa14cab0e',
#   'descr': 'Gamedec is a single-player cyberpunk isometric RPG. You are a game detective, who solves crimes inside virtual worlds. Use your wits to gather info from your witnesses and suspects, getting to the bottom of deceptive schemes. You are the sum of your choices.',
#   'namespace': 'b8abdf9f9bc64ed6b4128a71fd47607f',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '21894'},
#    {'id': '1367'},
#    {'id': '19847'},
#    {'id': '1370'},
#    {'id': '21147'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '15375'}]},
#  {'id': 'ef6a61163419450ba4dcf2eacb6b88e7',
#   'descr': "Aiko's Choice is a brand-new standalone addon to the beloved stealth tactics game Shadow Tactics. Set in Japan around the Edo period, you take control of kunoichi adept Aiko and her deadly assassin friends to hunt down the ghosts of her past.",
#   'namespace': '39c6dd5409944922a04cac3f59fbbcd4',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '21894'},
#    {'id': '1370'},
#    {'id': '1115'},
#    {'id': '9547'},
#    {'id': '1084'},
#    {'id': '9549'}]},
#  {'id': 'ecf4d2e87ea7445298c7471d8e9b405e',
#   'descr': 'Experience the definitive Dishonored collection. This complete compilation includes Dishonored as well as all of its additional content - Dunwall City Trials, The Knife of Dunwall, The Brigmore Witches and Void Walker’s Arsenal.',
#   'namespace': '766e1b59c32c447093add5efbc1a4858',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '21122'},
#    {'id': '1188'},
#    {'id': '21894'},
#    {'id': '21127'},
#    {'id': '9547'},
#    {'id': '15375'},
#    {'id': '21137'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '1333'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1336'},
#    {'id': '1370'},
#    {'id': '1084'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': '6e708b1e608f446eaa80488d26b7444b',
#   'descr': 'Explore more than a dozen unique areas in a Metroidvania style map. \nThe Fist, Drill, and Whip are three weapons with completely different fighting styles that offer seamless switching between high combo, high damage, and long range attacks. ',
#   'namespace': 'a7e2a2c51b9149c097b771926ed91877',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1216'},
#    {'id': '9547'},
#    {'id': '15375'},
#    {'id': '21137'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '21149'},
#    {'id': '1151'},
#    {'id': '1247'}]},
#  {'id': 'bd886035d7ee4eb1b886a5ada1358528',
#   'descr': 'LEGO Builder’s Journey is an atmospheric, geometric puzzle game that asks us to sometimes follow the instructions… and sometimes to break the rules.',
#   'namespace': 'ea533c2d54754167a9392a2ffa61bb87',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1296'},
#    {'id': '1298'},
#    {'id': '21894'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '15375'}]},
#  {'id': '1f723b00df58467998c4984ca39915ad',
#   'descr': "Them's Fightin' Herds",
#   'namespace': 'a567c32599bf4d4fb609e424f3691b39',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1344'},
#    {'id': '29088'},
#    {'id': '21122'},
#    {'id': '19847'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1263'},
#    {'id': '21119'}]},
#  {'id': '23ea1157ec89467d99f9b0fdf0ddb89b',
#   'descr': "You're the President now! The Saints have gone from the Penthouse to the White House - but Earth has been invaded and it’s up to you to save it with an arsenal of superpowers and strange weapons, in the wildest open world game ever.",
#   'namespace': '151e56468b5049628653dedab7c88007',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1264'},
#    {'id': '21109'},
#    {'id': '21894'},
#    {'id': '19847'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '9549'},
#    {'id': '15375'}]},
#  {},
#  {'id': '2ebc70bd2f0044a18e2734b4fcd9b48b',
#   'descr': 'Master the art of starfighter combat in the authentic piloting experience STAR WARS™: Squadrons. Buckle up, feel the adrenaline of first-person multiplayer space dogfights alongside your squadron, and learn what it means to be a pilot in a thrilling STAR WARS™ single-player st...',
#   'namespace': 'bc2b0372eaa448469cb9a769f27acea1',
#   'orig_price': 3999,
#   'fmt_orig_price': '$39.99',
#   'tags': [{'id': '1216'},
#    {'id': '1121'},
#    {'id': '1203'},
#    {'id': '19847'},
#    {'id': '22776'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '15375'}]},
#  {},
#  {'id': '44a89fd06011419d9df5fe412ab305e1',
#   'descr': 'Even the smallest person can make a big difference. Join Alba, as she sets out to save her beautiful island and its wildlife. And possibly start a revolution.',
#   'namespace': 'caf357c955344eaeaaaddb3c8357dbdf',
#   'orig_price': 1699,
#   'fmt_orig_price': '$16.99',
#   'tags': [{'id': '1296'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '15375'}]},
#  {'id': '559b16fa81134dce83b5b8b7cf67b5b3',
#   'descr': 'Take control of the most technologically advanced army in the Imperium - The Adeptus Mechanicus. Your every decision will weigh heavily on the outcome of the mission, in this turn-based tactical game. Will you be blessed by the Omnissiah?',
#   'namespace': '144f9e231e2846d1a4381d9bb678f69d',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '21122'},
#    {'id': '1188'},
#    {'id': '21894'},
#    {'id': '19847'},
#    {'id': '21127'},
#    {'id': '1386'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '21137'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1115'},
#    {'id': '21149'}]},
#  {'id': 'e5267e621ed14b84829c82a69e289c8e',
#   'descr': "A heavy metal inspired arcade combat with puzzle elements and gore galore. Stunning visuals and true old school gameplay accompanied by the most metal soundtrack you've ever heard.",
#   'namespace': '5a85738bd9e74940ad8409ed8a2c680a',
#   'orig_price': 1299,
#   'fmt_orig_price': '$12.99',
#   'tags': [{'id': '1216'},
#    {'id': '21109'},
#    {'id': '19847'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1151'},
#    {'id': '1263'}]},
#  {'id': '1578c50f725742fab1863952e01efc52',
#   'descr': "DRL Simulator® is the premier first-person view (FPV) racing game and simulator.  DRL SIM® offers a robust, evolving feature set, including high-intensity drone racing. It packs tracks that DRL's real world pilots compete on, with more added every season.",
#   'namespace': 'b6aa6a98bb394a53870bd6b026fefd1d',
#   'orig_price': 999,
#   'fmt_orig_price': '$9.99',
#   'tags': [{'id': '21121'},
#    {'id': '1188'},
#    {'id': '21125'},
#    {'id': '9547'},
#    {'id': '1393'},
#    {'id': '21138'},
#    {'id': '1203'},
#    {'id': '1299'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '21146'},
#    {'id': '1212'},
#    {'id': '21149'},
#    {'id': '10719'}]},
#  {'id': '16b7c8509ea8427898981145d244316c',
#   'descr': 'Stranded on the shores of a mysterious island, you must learn to survive. Use your cunning to kill or tame the primeval creatures roaming the land, and encounter other players to survive, dominate... and escape!',
#   'namespace': 'ark',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '21122'},
#    {'id': '1188'},
#    {'id': '21125'},
#    {'id': '21129'},
#    {'id': '9547'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1367'},
#    {'id': '1080'},
#    {'id': '1370'},
#    {'id': '21146'},
#    {'id': '21147'},
#    {'id': '1117'},
#    {'id': '21149'}]},
#  {},
#  {'id': '141eee80fbe041d48e16e7b998829295',
#   'descr': 'Winemaking could be your best adventure. Make the best wine interacting with soil and nature and take your winery to the top. Your beautiful journey into the winemaking tradition starts now.',
#   'namespace': '4d8b727a49144090b103f6b6ba471e71',
#   'orig_price': 2499,
#   'fmt_orig_price': '$24.99',
#   'tags': [{'id': '1188'},
#    {'id': '21894'},
#    {'id': '19847'},
#    {'id': '21127'},
#    {'id': '21130'},
#    {'id': '9547'},
#    {'id': '35244'},
#    {'id': '1263'},
#    {'id': '1393'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '21146'},
#    {'id': '1115'},
#    {'id': '21149'},
#    {'id': '10719'},
#    {'id': '21119'}]},
#  {},
#  {},
#  {},
#  {'id': '4d14124e8e9c484381db3be1e2118e8a',
#   'descr': "Fight against demons in your crusade to hunt down the Mother of Demons and stop Hell's invasion. As you battle through more than 30 action-packed levels, be on the lookout for enhanced weapons and secrets to help you put an end to the demonic threat.",
#   'namespace': '0ea70edafcc54b3191e262bbb6971981',
#   'orig_price': 499,
#   'fmt_orig_price': '$4.99',
#   'tags': [{'id': '1216'},
#    {'id': '1185'},
#    {'id': '21121'},
#    {'id': '1188'},
#    {'id': '21894'},
#    {'id': '21129'},
#    {'id': '9547'},
#    {'id': '1198'},
#    {'id': '15375'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': 'bd18a76d848946b0ac5f5c692c8b4757',
#   'descr': 'Boasting beautiful, hand-drawn animations and a re-orchestrated soundtrack, the cult classic returns with a unique blend of exploration, action, and adventure!',
#   'namespace': 'e1e92771f6774072bb1b8d0a0a6197f7',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1336'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1151'},
#    {'id': '1263'}]},
#  {'id': 'd8970826d8bb4d599a74ad990eb8ae01',
#   'descr': 'Unique, open-ended fantasy RPG in an alien land. Use battle or cunning to change the world, served by your army of custom-made mutant monsters. Tons of skills, treasures, factions, treasures, and creations. Unmatched freedom and replayability in an epic story.',
#   'namespace': '308652d49c89470fbf45fe8696b9c1c1',
#   'orig_price': 1995,
#   'fmt_orig_price': '$19.95',
#   'tags': [{'id': '21138'},
#    {'id': '21139'},
#    {'id': '1188'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '21894'},
#    {'id': '1367'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '21149'},
#    {'id': '10719'},
#    {'id': '1263'}]},
#  {'id': 'a125d72a47a1490aba78c4e79a40395d',
#   'descr': 'It is the digital adaptation of the top-selling strategy board game from Fantasy Flight Games.',
#   'namespace': '1b737464d3c441f8956315433be02d3b',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '29088'},
#    {'id': '1188'},
#    {'id': '21125'},
#    {'id': '19847'},
#    {'id': '9547'},
#    {'id': '15375'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '1115'},
#    {'id': '21149'}]},
#  {'id': '04aedb34af844dc1869c1b99aa1b5541',
#   'descr': 'Aliens rule Earth, but secretly hiding a sinister agenda. As the leader of a guerrilla force, you must ignite a global resistance to eliminate the alien threat and save the human race.',
#   'namespace': '7ec453d446194b8f8afe82aaa9561211',
#   'orig_price': 5999,
#   'fmt_orig_price': '$59.99',
#   'tags': [{'id': '1088'},
#    {'id': '1120'},
#    {'id': '1312'},
#    {'id': '21122'},
#    {'id': '1188'},
#    {'id': '1254'},
#    {'id': '21894'},
#    {'id': '21127'},
#    {'id': '21129'},
#    {'id': '9547'},
#    {'id': '15375'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '1115'},
#    {'id': '21149'}]},
#  {'id': 'bb3ce2b4668b4b22aae989f4508f0b71',
#   'descr': 'The critically-acclaimed Total War: WARHAMMER combines a turn-based campaign of epic empire-building with colossal and explosive real-time battles, set within the incredible world of Warhammer Fantasy Battles. ',
#   'namespace': '0c321ac6d5fe49139c153253b60702f4',
#   'orig_price': 5999,
#   'fmt_orig_price': '$59.99',
#   'tags': [{'id': '1088'},
#    {'id': '1120'},
#    {'id': '1216'},
#    {'id': '21122'},
#    {'id': '1188'},
#    {'id': '21125'},
#    {'id': '21129'},
#    {'id': '9547'},
#    {'id': '1264'},
#    {'id': '21138'},
#    {'id': '1203'},
#    {'id': '1299'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '1115'},
#    {'id': '21149'}]},
#  {'id': '08f2539567df4d43a1b0f8a5196f43cc',
#   'descr': "TURBO CHARGED PINBALL RETURNS! Now with bigger sprites, more baddies, more secrets & MORE BULLETS! Demon's Tilt pushes the limits of the Video Pinball genre with SHMUP & Hack N' Slash elements.",
#   'namespace': 'c4a39e8e304c4356afcddd79820b223d',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '21121'},
#    {'id': '1218'},
#    {'id': '19847'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '10719'},
#    {'id': '15375'}]},
#  {},
#  {'id': '12bc396a4c904ebc9db002bcee13832a',
#   'descr': 'Guide two brothers on an epic journey of discovery, loss, adventure and mystery remade for the latest generation of graphics, performance, and gameplay.  \n\nPlay in single-player mode or local co-op with a friend.\n\nThis is one journey you will never forget.',
#   'namespace': '0246b51e02da40329ad6d20f5c8dc631',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1264'},
#    {'id': '21894'},
#    {'id': '19847'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'}]},
#  {'id': 'f6d665930cc34c34ac69cfe52906a723',
#   'descr': 'Pilot your fully customizable Arsenal mech and join your fellow mercenaries in defending humanity from the corrupted machines and gigantic robots in this post-apocalyptic action game!',
#   'namespace': '0dc18227b3f14162968d8e7969e454ef',
#   'orig_price': 4999,
#   'fmt_orig_price': '$49.99',
#   'tags': [{'id': '1216'},
#    {'id': '21121'},
#    {'id': '21122'},
#    {'id': '21894'},
#    {'id': '9547'},
#    {'id': '1264'},
#    {'id': '21137'},
#    {'id': '21138'},
#    {'id': '1203'},
#    {'id': '21139'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': '1c5143aeec774495a5acc9d613af181b',
#   'descr': 'Armed only with raw instincts and the ability to push beyond the limits of human endurance, Lara must fight to unravel the dark history of a forgotten island to escape its relentless hold.',
#   'namespace': 'caca23a0954f4c1aba1fdd7e277b81e2',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '21122'},
#    {'id': '1188'},
#    {'id': '21127'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '15375'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '1117'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {},
#  {'id': '8b8f6bb0adb0477eb3841748f3d95aa4',
#   'descr': 'A premium edition of the Pathfinder Kingmaker experience! A premium downloadable copy of the game which contains 2 in-game items.  All 3 full DLCs...',
#   'namespace': '6daaf10529e94fccaa8ee43b66adbe4a',
#   'orig_price': 3999,
#   'fmt_orig_price': '$39.99',
#   'tags': [{'id': '1333'},
#    {'id': '21894'},
#    {'id': '1367'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '10719'},
#    {'id': '15375'}]},
#  {},
#  {},
#  {},
#  {'id': '7b0d120a875547e9bec70192ddcc96e2',
#   'descr': 'Experience an atmospheric hunting game like no other in this realistic and visually breathtaking open world. Immerse yourself in the atmospheric single player campaign, or share the ultimate hunting experience with friends.',
#   'namespace': 'c7f9346e3db148fca6dd63e9dd8451bd',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1188'},
#    {'id': '9547'},
#    {'id': '1294'},
#    {'id': '1264'},
#    {'id': '1393'},
#    {'id': '21138'},
#    {'id': '1203'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '21146'},
#    {'id': '1307'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': 'fc75b7c573c64c24a937823183f8468e',
#   'descr': 'Now fully rebuilt and remastered, Guild of Dungeoneering Ultimate Edition is a turn-based dungeon crawler with a twist: instead of controlling the hero you build the dungeon around them. ',
#   'namespace': 'e04dd85a41d740ac972df346afd913a6',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '21894'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1181'},
#    {'id': '10719'}]},
#  {'id': 'b8bf369a354e4a01b01d61d750b1bc6d',
#   'descr': 'An upside-down digital/analogue universe created from original artwork and recordings to commemorate 21 years of Radiohead’s Kid A and Amnesiac. Coming in November 2021. Add it to your wishlist now.',
#   'namespace': '72eb87039aa74e82a4b873c276de61e3',
#   'orig_price': 0,
#   'fmt_orig_price': '0',
#   'tags': [{'id': '1381'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1294'},
#    {'id': '10719'}]},
#  {},
#  {},
#  {'id': '2a112cd37b774426990583a259e25ef9',
#   'descr': 'Among the Sleep: Enhanced Edition is a new and improved version of the award winning first person horror adventure. In the game you play as a small child trapped in a weird nightmare where you go looking for your mom.',
#   'namespace': '53ef2f4592684c4c97d6d32e40467274',
#   'orig_price': 1699,
#   'fmt_orig_price': '$16.99',
#   'tags': [{'id': '1218'},
#    {'id': '21894'},
#    {'id': '19847'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '9549'},
#    {'id': '10719'},
#    {'id': '1263'}]},
#  {'id': 'f28ce458986e4f8dbbf67be5d0ac41e6',
#   'descr': "Meet Yoku, the pint-sized postman protagonist of Yoku's Island Express! Use a unique blend of pinball mechanics, platforming and open world exploration to unlock the secrets of Mokumana Island.",
#   'namespace': '54399b3ef40d4c568e5904607470ffe9',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1336'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '1247'},
#    {'id': '1263'},
#    {'id': '15375'}]},
#  {'id': '822ad2aee1ff4b2da5dd03a995527821',
#   'descr': 'Experience The Full Package, Remastered.                        Steelport, the original city of sin, has never looked so good as it drowns in sex, drugs and guns. The Third Street Saints are at the height of power and yours to control. This is your city. These are your rules.',
#   'namespace': '3928fd8975b2437d894bbc5cd21de9a0',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1216'},
#    {'id': '21122'},
#    {'id': '1188'},
#    {'id': '21126'},
#    {'id': '9547'},
#    {'id': '15375'},
#    {'id': '21138'},
#    {'id': '1203'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '21149'},
#    {'id': '1279'},
#    {'id': '21119'}]},
#  {'id': '240096b07cf94eaba1d3695221127d89',
#   'descr': 'The evolution of train simulation! Master iconic locomotives on high-speed services, long freight hauls or precise commuter traffic, and get creative with customisation tools in this advanced sequel. Climb into the cab in Train Sim World 2.',
#   'namespace': 'd8d8b399f3d14ac2b9b75870329a68dd',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1188'},
#    {'id': '21127'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '21135'},
#    {'id': '1393'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '21146'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': '1786c8d9cd474bef9ce221929411633f',
#   'descr': 'Hell is Other Demons is an action-platform shooter, with Roguelite elements. Explore a sprawling, hand-crafted world full of demons, insanely over-the-top boss fights, and a heavy synthwave soundtrack.',
#   'namespace': '643a8667d7a940b8b36094020fcd0dcf',
#   'orig_price': 999,
#   'fmt_orig_price': '$9.99',
#   'tags': [{'id': '21894'},
#    {'id': '1210'},
#    {'id': '1370'},
#    {'id': '1083'},
#    {'id': '9547'},
#    {'id': '1151'},
#    {'id': '10719'}]},
#  {},
#  {},
#  {'id': 'ed820853b9f649ac93e2456b2362220d',
#   'descr': 'The Lion’s Song is a narrative adventure game. It is steeped in early 20th century history and focusses on a cast of Austrian artists and scientists with each episode taking a closer look at their intimate struggles with creativity and inspiration.',
#   'namespace': 'e35a5826457c4c98aada2ffad7b5ea5d',
#   'orig_price': 799,
#   'fmt_orig_price': '$7.99',
#   'tags': [{'id': '1395'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '35244'},
#    {'id': '1117'},
#    {'id': '10719'}]},
#  {},
#  {'id': 'ded5930173d5495993186871fbfd329a',
#   'descr': "12th century, England: In a time of poverty and war, a small town begins the construction of a cathedral to claim safety for its people. In their struggle to survive, destinies intertwine. Based on Ken Follett's world-bestseller ‘The Pillars of the Earth’.",
#   'namespace': 'ce8393adfbf342ceab0a36479ffbc627',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1298'},
#    {'id': '1395'},
#    {'id': '21123'},
#    {'id': '21894'},
#    {'id': '19847'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '9549'},
#    {'id': '21151'}]},
#  {},
#  {'id': '26c8bec5ae4f44b6b942b9564e81cafc',
#   'descr': 'RAGE 2 brings together two studio powerhouses – Avalanche Studios, masters of open world insanity, and id Software, creators of the first-person shooter – to deliver a carnival of carnage where you can go anywhere, shoot anything, and explode everything.',
#   'namespace': '2736ab9fec9c4a93a7a2872ed5154d4b',
#   'orig_price': 3999,
#   'fmt_orig_price': '$39.99',
#   'tags': [{'id': '1216'},
#    {'id': '1185'},
#    {'id': '1188'},
#    {'id': '21894'},
#    {'id': '9547'},
#    {'id': '15375'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1307'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': '55e88d9d4c864d53ba3a03f58222ed24',
#   'descr': 'For The King',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1264'},
#    {'id': '1386'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '10719'}]},
#  {'id': 'ea7721c6c2694e72813d3661bc68a2cb',
#   'descr': 'Put your mastery of the blaster, lightsaber, and the Force to the test online and offline in STAR WARS™ Battlefront™ II: Celebration Edition',
#   'namespace': 'b156c3365a5b4cb9a01a5e1108b4e3f4',
#   'orig_price': 3999,
#   'fmt_orig_price': '$39.99',
#   'tags': [{'id': '1216'},
#    {'id': '1264'},
#    {'id': '1203'},
#    {'id': '19847'},
#    {'id': '1210'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '15375'}]},
#  {'id': '2373a0ce09bd43d695088c8335758178',
#   'descr': "The eagerly awaited follow-up to Red Hook's smash hit gothic horror RPG!  DDII will test your mettle and drive you to the brink of madness. Armor yourself with purpose and provision your party for the journey ahead. It will be arduous.",
#   'namespace': '6ff9efdef6dc45ecb40ed20fcd2c4621',
#   'orig_price': 3999,
#   'fmt_orig_price': '$39.99',
#   'tags': [{'id': '1088'},
#    {'id': '21122'},
#    {'id': '21894'},
#    {'id': '19847'},
#    {'id': '21127'},
#    {'id': '21129'},
#    {'id': '9547'},
#    {'id': '21137'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1367'},
#    {'id': '1370'},
#    {'id': '1115'},
#    {'id': '21147'},
#    {'id': '21149'}]},
#  {'id': 'a020424f6c854cefac41f4af4a0ce69f',
#   'descr': "Explore ancient ruins, dodge carnivorous beasts and avoid trigger-happy guards as Abe, the original Oddworld hero in this lovingly recrafted, built from the ground-up and totally recooked take on the classic adventure Oddworld: Abe's Oddysee.",
#   'namespace': '56eab841eaab4016b9fedd2350f997b6',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1298'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '21150'},
#    {'id': '1151'}]},
#  {'id': '6238fdbc5a0143ccbc8448a8009bcef5',
#   'descr': 'Experience the game that revitalized the classic RPG genre in a complete and definitive package that includes every expansion, bonus, and update, presenting Pillars of Eternity at its best.',
#   'namespace': '25e53de2e4ab4da8aa589d881273a11c',
#   'orig_price': 3999,
#   'fmt_orig_price': '$39.99',
#   'tags': [{'id': '21122'},
#    {'id': '1188'},
#    {'id': '19847'},
#    {'id': '21127'},
#    {'id': '21129'},
#    {'id': '9547'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1367'},
#    {'id': '1370'},
#    {'id': '21147'},
#    {'id': '21149'}]},
#  {'id': '8a9ebc1feff6402e9b88839f46ee45ac',
#   'descr': 'Experience a story-driven RPG where your choices mean all the difference in the world. Tyranny – Gold Edition, the ultimate Tyranny experience that includes every Tyranny Expansion and all additional DLC.',
#   'namespace': '2462202651534bf7b4b4e0ea960be8ac',
#   'orig_price': 4999,
#   'fmt_orig_price': '$49.99',
#   'tags': [{'id': '1216'},
#    {'id': '21122'},
#    {'id': '21127'},
#    {'id': '9547'},
#    {'id': '15375'},
#    {'id': '21137'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1367'},
#    {'id': '21147'},
#    {'id': '1117'},
#    {'id': '21149'}]},
#  {'id': 'c98c8c591fdb472e97dc3169b097218a',
#   'descr': 'Kingdom New Lands',
#   'namespace': 'epic',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1393'},
#    {'id': '1080'},
#    {'id': '1370'},
#    {'id': '1115'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '9549'}]},
#  {},
#  {'id': '4ec50a302f1449b3bf706a199c333ab8',
#   'descr': 'Build the park of a lifetime and rediscover the critically acclaimed rollercoaster simulation bestseller. Feel the thrill of a genre-defining classic, complete with two huge expansion packs.',
#   'namespace': 'f01b3e0178d448f0b93911e292d8e614',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1188'},
#    {'id': '21127'},
#    {'id': '21130'},
#    {'id': '9547'},
#    {'id': '15375'},
#    {'id': '21136'},
#    {'id': '1393'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '1115'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': '0d25ff58568a41feb949ef3fc7cf8e13',
#   'descr': 'Hard hat tester, Ray, has a bizarre accident and wakes up with a giant pink spaghetti arm sticking out of his brain! With his awesome new powers he can read minds and change the world with stickers but he’s on the run for a crime he didn’t commit.',
#   'namespace': 'ad876f7812c946f6a362bf821b971b48',
#   'orig_price': 799,
#   'fmt_orig_price': '$7.99',
#   'tags': [{'id': '1216'},
#    {'id': '21894'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '1151'},
#    {'id': '15375'}]},
#  {'id': '44d7537f61f24ed786e5c369a674ee86',
#   'descr': 'Football Manager 2020 In-game Editor',
#   'namespace': 'c1ccf2ba1bc1473abb6ca5168e1a670c',
#   'orig_price': 549,
#   'fmt_orig_price': '$5.49',
#   'tags': []},
#  {'id': '72cbf73f83ea4437b142e143a1c78562',
#   'descr': 'Where the Water Tastes Like Wine is a Narrative-Adventure game about traveling, sharing stories, and surviving manifest destiny. Players wander across a folkloric Depression era United States at their own pace, meeting strangers with their own stories to tell.',
#   'namespace': '27d2f156f77b4202b9bc78e40a408b03',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1395'},
#    {'id': '21894'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'}]},
#  {'id': '80260982798c4573a4241e50229e81b1',
#   'descr': "Shadowrun: Hong Kong - Extended Edition is the capstone title in Harebrained Schemes' Shadowrun series - and includes the all-new, 6+ hr Shadows of Hong Kong Bonus Campaign.",
#   'namespace': '0d66818e2304485f8dc3ae90c8b622b4',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1367'},
#    {'id': '1386'},
#    {'id': '21147'},
#    {'id': '9547'},
#    {'id': '1263'},
#    {'id': '15375'}]},
#  {'id': '71489603554f452f9d71e93627115939',
#   'descr': "Harebrained Schemes' biggest Shadowrun game to date, and the definitive Shadowrun RPG experience available on PC. A standalone title with tons of new content & improvements!",
#   'namespace': '805a1b31b65f4c3db221ab242f894482',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1287'},
#    {'id': '1367'},
#    {'id': '1386'},
#    {'id': '1115'},
#    {'id': '21147'},
#    {'id': '9547'},
#    {'id': '15375'}]},
#  {},
#  {'id': '8f6f05aa00fd48cca99d897b593b3e8b',
#   'descr': 'Slay enemies with speed and precision in an over-the-top show of blood and explosions. Play solo or with others, make split-second decisions, dodge bullets, and use weapons and abilities to inflict violence in the most graphic way possible.',
#   'namespace': 'ceaa24233cdb4b678a1cf515e3a912e8',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1216'},
#    {'id': '21109'},
#    {'id': '1258'},
#    {'id': '9547'},
#    {'id': '1263'}]},
#  {'id': 'b5dba5ebbdf84ecaad0edf4f5e026247',
#   'descr': "Wilmot's Warehouse is a puzzle game about keeping a warehouse running in tip-top shape. Just remember where you put everything, because when the service hatch opens, you'll need to find the things people want quickly, to earn the coveted Performance Stars.",
#   'namespace': 'f697ab7aa6af41f880e1489818e2720d',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1264'},
#    {'id': '1298'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '10719'},
#    {'id': '1263'}]},
#  {'id': 'eb38399025864ffb88a7e027d02502a8',
#   'descr': 'Midge joins Shovelworks Studios as a new animator, but not all is as it seems at the studio.',
#   'namespace': 'd9090f3f39f64d5bb827c6e44b95cff0',
#   'orig_price': 0,
#   'fmt_orig_price': '0',
#   'tags': [{'id': '1216'}, {'id': '1141'}, {'id': '1370'}, {'id': '9547'}]},
#  {},
#  {'id': '16b7c8509ea8427898981145d244316c',
#   'descr': 'Stranded on the shores of a mysterious island, you must learn to survive. Use your cunning to kill or tame the primeval creatures roaming the land, and encounter other players to survive, dominate... and escape!',
#   'namespace': 'ark',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '21122'},
#    {'id': '1188'},
#    {'id': '21125'},
#    {'id': '21129'},
#    {'id': '9547'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1367'},
#    {'id': '1080'},
#    {'id': '1370'},
#    {'id': '21146'},
#    {'id': '21147'},
#    {'id': '1117'},
#    {'id': '21149'}]},
#  {'id': 'b3678744f16842debd1f2d57fbe12e9c',
#   'descr': 'The ULTIMATE collection is here! Six NEOGEO titles as well as one mysterious, unreleased game are featured! Featuring Online Battle Modes as well as a Museum Mode and Music Player. This collection is a must-have for all SAMURAI SHODOWN fans across the globe!',
#   'namespace': '3e84a6d0684b4f7593e6bf88bee0cbaf',
#   'orig_price': 3999,
#   'fmt_orig_price': '$39.99',
#   'tags': [{'id': '1344'}, {'id': '1203'}, {'id': '21894'}, {'id': '9547'}]},
#  {'id': 'fe74b3dad04846e5a58f62aebd3858b6',
#   'descr': 'Civilization VI offers new ways to interact with your world, expand your empire across the map, advance your culture, and compete against history’s greatest leaders to build a civilization that will stand the test of time.',
#   'namespace': 'cd14dcaa4f3443f19f7169a980559c62',
#   'orig_price': 5999,
#   'fmt_orig_price': '$59.99',
#   'tags': [{'id': '1088'},
#    {'id': '21122'},
#    {'id': '1188'},
#    {'id': '21127'},
#    {'id': '1386'},
#    {'id': '9547'},
#    {'id': '1166'},
#    {'id': '15375'},
#    {'id': '21138'},
#    {'id': '1203'},
#    {'id': '1299'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '21146'},
#    {'id': '1115'},
#    {'id': '21149'}]},
#  {'id': '55e88d9d4c864d53ba3a03f58222ed24',
#   'descr': 'For The King',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1264'},
#    {'id': '1386'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '10719'}]},
#  {},
#  {'id': '84f8d79ca9d84057ba4406d215cb6ad5',
#   'descr': 'Everything in Tormentor ❌ Punisher can be killed in one hit, including bosses and yourself. Bosses change the shape of the arena, conjuring rooms and traps to make it more hellish and brutal. Demons adjust to your play style and punish you accordingly. Explore and discover new...',
#   'namespace': '51c19c28a7024793b9e38174d0e1634b',
#   'orig_price': 799,
#   'fmt_orig_price': '$7.99',
#   'tags': [{'id': '1216'}, {'id': '9547'}, {'id': '22924'}, {'id': '1263'}]},
#  {'id': '02950ab2195f44dbb665264229b015c7',
#   'descr': "Assassin's Creed Syndicate AC Assassins Syndicate",
#   'namespace': 'epic',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1216'},
#    {'id': '1370'},
#    {'id': '1307'},
#    {'id': '9547'},
#    {'id': '1084'},
#    {'id': '9549'}]},
#  {'id': '4530e0cba368471fbee9107df203c2e4',
#   'descr': 'Darksiders II Deathinitive Edition',
#   'namespace': 'epic',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1216'},
#    {'id': '1367'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '9549'}]},
#  {'id': '1045fb691c15439c9f9a41d755b1a80e',
#   'descr': 'DARKSIDERS: GENESIS gives players their first look at the world of DARKSIDERS before the events of the original game. Furthermore, it introduces the fourth and last horseman STRIFE, as well as Co-op gameplay for the first time in the history of the franchise.',
#   'namespace': '9bcf72043732431397782f3a32efbbd5',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1216'},
#    {'id': '1264'},
#    {'id': '1203'},
#    {'id': '21109'},
#    {'id': '19847'},
#    {'id': '1336'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '15375'}]},
#  {'id': 'be60529b869c4a8dae064311aefdd1bd',
#   'descr': 'SUPERHOT',
#   'namespace': 'epic',
#   'orig_price': 2499,
#   'fmt_orig_price': '$24.99',
#   'tags': [{'id': '1216'},
#    {'id': '1370'},
#    {'id': '1210'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1263'}]},
#  {'id': 'a9a4ab65b8cb405198e2332795b69be6',
#   'descr': 'RUINER',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1370'},
#    {'id': '1210'},
#    {'id': '9547'},
#    {'id': '1117'}]},
#  {'id': 'c7aaa2e680fd4dceb5fc87eebe80ade9',
#   'descr': 'The year is 2084. In a dark cyberpunk world shattered by plagues and wars, become a neural police detective and hack into the jagged minds of others. Make use of anything they felt, thought, or remembered to solve the case and catch the elusive killer.',
#   'namespace': '71e66acf6bb34733bd98514ebf9fcaf8',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1218'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '1294'}]},
#  {'id': '9714d370b31d44c68b80921b7fb994c8',
#   'descr': 'Batman™: Arkham Knight',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1344'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1084'},
#    {'id': '9549'}]},
#  {},
#  {},
#  {'id': '5d701b13e9fb423aa53553fc94112bce',
#   'descr': 'LEGO® Batman™ 3: Beyond Gotham',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1264'},
#    {'id': '1370'},
#    {'id': '1307'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '9549'}]},
#  {'id': 'ad6b9e6c4cfc4b959ce44ecad7565c7b',
#   'descr': 'LEGO® Batman™ 2: DC Super Heroes',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1264'},
#    {'id': '1370'},
#    {'id': '1307'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '9549'}]},
#  {'id': '559ac60ab99244e1a6c8c80a6194b257',
#   'descr': 'LEGO® Batman™ The Videogame',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1264'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1116'},
#    {'id': '1117'},
#    {'id': '9549'}]},
#  {'id': 'f77ae52ec98e4c218ca7a0da76c1eb93',
#   'descr': 'The End is Nigh',
#   'namespace': 'epic',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1216'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1151'},
#    {'id': '1263'}]},
#  {},
#  {'id': 'c98c8c591fdb472e97dc3169b097218a',
#   'descr': 'Kingdom New Lands',
#   'namespace': 'epic',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1393'},
#    {'id': '1080'},
#    {'id': '1370'},
#    {'id': '1115'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '9549'}]}]

# %%
# single_get(getname(1))
# for only 752pm data
miss_df2 = pd.DataFrame(miss_df)
miss_df2.head()

# if rerunning after I returned error handling to single_get instead of get_better_gamadata:
# miss_df3 = [d if d is not None else {} for d in miss_df]
# miss_df3 = pd.DataFrame(miss_df3)

# JUST RAN 8pm
# miss_df2.to_csv("~/Desktop/dshw/EGS_project/df_missings.csv", index = True)

miss_df2["OG_index"] = miss_inds
miss_df2["Name"] = miss_names

miss_df2 = miss_df2.set_index('OG_index')
# print(miss_df2.head())

# print(dff.head())
withmiss_df = dff.combine_first(miss_df2)
withmiss_df.head()
# withmiss_df.shape

withmiss_df.to_csv("~/Desktop/dshw/EGS_project/df_complete.csv", index = True)

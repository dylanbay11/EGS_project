# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import re
import time
import json
# currently due to venv + VSCode issues, only runs in jupyter notebooks from command line

# Epic Games Store API wrapper from https://epicstore-api.readthedocs.io/en/latest/index.html
import epicstore_api
from epicstore_api import EpicGamesStoreAPI, OfferData
api = EpicGamesStoreAPI()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 7
#       5 import re
#       6 import time
# ----> 7 import epicstore_api
#
# ModuleNotFoundError: No module named 'epicstore_api'

# %%
# grab initial table of all free epic games via scraping, saved as soup object
gameurl = "https://www.steamgifts.com/discussion/S4e2c/free-epic-games-store-list-of-all-weekly-free-games-every-thursday-at-11-am-et"
r = requests.get(gameurl)
r.status_code
gsoup = BeautifulSoup(r.text)
gtable = gsoup.find("table")
# Out:
# 200

# %%
# proceed throughout rows and grab the text (could also have used pd.read_html)
table_rows = gtable.find_all('tr')
result = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td if tr.text.strip()]
    if row:
        result.append(row)
gdf = pd.DataFrame(result, columns=["Number", "Name", "Start", "End"])
# gdf
# above code adapted from https://stackoverflow.com/questions/50633050/scrape-tables-into-dataframe-with-beautifulsoup
# Out:
#     Number                         Name       Start         End
# 0      477                   The Bridge   3/14/2024   3/21/2024
# 1      476     Deus Ex: Mankind Divided   3/14/2024   3/21/2024
# 2      475                 Astro Duel 2    3/7/2024   3/14/2024
# 3      474  Aerial_Knight’s Never Yield   2/29/2024    3/7/2024
# 4      473       Super Meat Boy Forever   2/22/2024   2/29/2024
# ..     ...                          ...         ...         ...
# 472      5                  Axiom Verge    2/7/2019   2/22/2019
# 473      4       The Jackbox Party Pack   1/24/2019    2/7/2019
# 474      3  What Remains of Edith Finch   1/11/2019   1/24/2019
# 475      2               Super Meat Boy  12/28/2018   1/10/2019
# 476      1                   Subnautica  12/12/2018  12/27/2018
#
# [477 rows x 4 columns]

# %%
# grabbing links to Epic Games Store pages separately from same scraped table
links = []
for tr in table_rows:
    td = tr.find_all('td')
    for cell in td:
        link = cell.find('a')
        if link:
            links.append(link['href'].strip())

links_series = pd.Series(links)
# links_series
# above chunk adapted from chatGPT corrections of own orginal code

# tacking on to original df since shares index/order
gdf["Link"] = links_series
gdf
# Out:
#     Number                         Name       Start         End  \
# 0      477                   The Bridge   3/14/2024   3/21/2024
# 1      476     Deus Ex: Mankind Divided   3/14/2024   3/21/2024
# 2      475                 Astro Duel 2    3/7/2024   3/14/2024
# 3      474  Aerial_Knight’s Never Yield   2/29/2024    3/7/2024
# 4      473       Super Meat Boy Forever   2/22/2024   2/29/2024
# ..     ...                          ...         ...         ...
# 472      5                  Axiom Verge    2/7/2019   2/22/2019
# 473      4       The Jackbox Party Pack   1/24/2019    2/7/2019
# 474      3  What Remains of Edith Finch   1/11/2019   1/24/2019
# 475      2               Super Meat Boy  12/28/2018   1/10/2019
# 476      1                   Subnautica  12/12/2018  12/27/2018
#
#                                                   Link
# 0       https://store.epicgames.com/en-US/p/the-bridge
# 1    https://store.epicgames.com/en-US/p/deus-ex-ma...
# 2    https://store.epicgames.com/en-US/p/astro-duel...
# 3    https://store.epicgames.com/en-US/p/aerial-kni...
# 4    https://store.epicgames.com/en-US/p/super-meat...
# ..                                                 ...
# 472    https://store.epicgames.com/en-US/p/axiom-verge
# 473  https://store.epicgames.com/en-US/p/jackbox-pa...
# 474  https://store.epicgames.com/en-US/p/what-remai...
# 475  https://store.epicgames.com/en-US/p/super-meat...
# 476     https://store.epicgames.com/en-US/p/subnautica
#
# [477 rows x 5 columns]

# %%
testurl = "https://store.epicgames.com/en-US/p/the-bridge"
rtest = requests.get(testurl)
rtest.status_code
# I think these pages are protected from scraping directly. Rather than use Selenium, on to APIs...
# Out:
# 403

# %%
# the following will attempt to get just a single test entry, matched from search results

testgame = api.fetch_store_games(keywords = "The Bridge")
# testgame The Bridge, sometimes fails, but "Blue Oak Bridge" (not in dataset) always works as a tester

title_to_find = "Blue Oak Bridge"
matching_item = None

for element in testgame["data"]["Catalog"]["searchStore"]["elements"]:
    if element["title"] == title_to_find:
        matching_item = element
        break

if matching_item:
    print("Title:", matching_item["title"])
    print("Description:", matching_item["description"])
    # You can extract other fields as needed
else:
    print("Title not found.")

# print(matching_item)
print("Price:", matching_item["price"]["totalPrice"]["originalPrice"], "\n")

# PRETTY JSON PRINTING
def jprint(j):
    print(json.dumps(j, indent = 2, default = str))
jprint(matching_item)
# Out:
# Title: Blue Oak Bridge
# Description: Blue Oak Bridge features breathtaking 2D hand-painted art in a storybook world of powerful witches, ancient magic and royal secrets. Farm, forage and fish throughout the island of Eloria and use all you discover to brew potions, make produce and help your new friends.
# 2499
# {
#   "title": "Blue Oak Bridge",
#   "id": "aada95beab7c4671aa7cb3a6bb48c586",
#   "namespace": "4dbe3446fbe1495a822cbea817f5606e",
#   "description": "Blue Oak Bridge features breathtaking 2D hand-painted art in a storybook world of powerful witches, ancient magic and royal secrets. Farm, forage and fish throughout the island of Eloria and use all you discover to brew potions, make produce and help your new friends.",
#   "effectiveDate": "2024-02-13T17:36:43.151Z",
#   "keyImages": [
#     {
#       "type": "OfferImageWide",
#       "url": "https://cdn1.epicgames.com/spt-assets/7faa14ae76ee4c15ae9d983ffc25224d/blue-oak-bridge-jd61u.jpg"
#     },
#     {
#       "type": "OfferImageTall",
#       "url": "https://cdn1.epicgames.com/spt-assets/7faa14ae76ee4c15ae9d983ffc25224d/blue-oak-bridge-nl6zl.jpg"
#     },
#     {
#       "type": "Thumbnail",
#       "url": "https://cdn1.epicgames.com/spt-assets/7faa14ae76ee4c15ae9d983ffc25224d/blue-oak-bridge-nl6zl.jpg"
#     }
#   ],
#   "seller": {
#     "id": "o-evvkvpu854fgu9ylqxwn8yuzqe4a8q",
#     "name": "Lemon Seed Studio"
#   },
#   "productSlug": null,
#   "urlSlug": "ea4496cc08ea4b8d87d0fda172256a79",
#   "url": null,
#   "tags": [
#     {
#       "id": "1393"
#     },
#     {
#       "id": "1367"
#     },
#     {
#       "id": "1370"
#     },
#     {
#       "id": "9547"
#     },
#     {
#       "id": "9549"
#     },
#     {
#       "id": "1263"
#     }
#   ],
#   "items": [
#     {
#       "id": "50bd5de53e6e4863a383fd36bc855329",
#       "namespace": "4dbe3446fbe1495a822cbea817f5606e"
#     }
#   ],
#   "customAttributes": [
#     {
#       "key": "autoGeneratedPrice",
#       "value": "false"
#     },
#     {
#       "key": "isManuallySetViewableDate",
#       "value": "true"
#     },
#     {
#       "key": "isManuallySetPCReleaseDate",
#       "value": "true"
#     },
#     {
#       "key": "isBlockchainUsed",
#       "value": "false"
#     }
#   ],
#   "categories": [
#     {
#       "path": "games/edition/base"
#     },
#     {
#       "path": "games/edition"
#     },
#     {
#       "path": "games"
#     }
#   ],
#   "price": {
#     "totalPrice": {
#       "discountPrice": 2499,
#       "originalPrice": 2499,
#       "voucherDiscount": 0,
#       "discount": 0,
#       "currencyCode": "USD",
#       "currencyInfo": {
#         "decimals": 2
#       },
#       "fmtPrice": {
#         "originalPrice": "$24.99",
#         "discountPrice": "$24.99",
#         "intermediatePrice": "$24.99"
#       }
#     },
#     "lineOffers": [
#       {
#         "appliedRules": []
#       }
#     ]
#   }
# }

# %%
# I now try to elaborate and extend the above approach with my own function

def get_gamedata(gamename, searchsize = 5):
    # takes a string gamename, searches for it (defaults to 5 search results), finds exact name/title match
    # returns dict with id, descr[iption], namespace, orig[inal]_price, fmt_orig_price (nicely formatted), and tags (list)
    dict = api.fetch_store_games(count = searchsize, keywords = gamename)
    match = None
    for element in dict["data"]["Catalog"]["searchStore"]["elements"]:
        if element["title"] == gamename:
            match = element
            break

    return_dict = {
    "id": match["id"],
    "descr": match["description"],
    "namespace": match["namespace"],
    "orig_price": match["price"]["totalPrice"]["originalPrice"],
    "fmt_orig_price": match["price"]["totalPrice"]["fmtPrice"]["originalPrice"],
    "tags": match["tags"]  # list but looks like individual dicts
    #TODO: possibly format the tags better
    #TODO: there might be one or two relevant pieces more to grab
    }
    return return_dict

    # alternative (decided against) where return is LIST type:
    # return [match["id"], match["description"], match["namespace"], match["price"]["totalPrice"]["originalPrice"],
    #         match["price"]["totalPrice"]["fmtPrice"]["originalPrice"]]

# I should mention that a few of the api calls might need other bits from the API JSON, but it's a bit unclear
# for example, slugs, namespace, various ID types all poorly defined and unclear when unique or extensible

# Let's test again with a single entry (same as previous)
jprint(get_gamedata("Blue Oak Bridge"))
# Out:
# {'id': 'aada95beab7c4671aa7cb3a6bb48c586', 'descr': 'Blue Oak Bridge features breathtaking 2D hand-painted art in a storybook world of powerful witches, ancient magic and royal secrets. Farm, forage and fish throughout the island of Eloria and use all you discover to brew potions, make produce and help your new friends.', 'namespace': '4dbe3446fbe1495a822cbea817f5606e', 'orig_price': 2499, 'fmt_orig_price': '$24.99', 'tags': [{'id': '1393'}, {'id': '1367'}, {'id': '1370'}, {'id': '9547'}, {'id': '9549'}, {'id': '1263'}]}

# %%
# example of weird tag formatting, currently list of dict-like elements
blueoak = get_gamedata("Blue Oak Bridge")
blueoak["tags"]
# see url for tag readable names https://epicstore-api.readthedocs.io/en/latest/models.html
#TODO: find a good way to include these tags in a more readable, cleaned way in final dataset for analysis
# Out:
# [{'id': '1393'},
#  {'id': '1367'},
#  {'id': '1370'},
#  {'id': '9547'},
#  {'id': '9549'},
#  {'id': '1263'}]

# %%
# setting up a wrapped function to test other titles, eventually for the whole table, but to respect rate limits
def single_get(name, sleep_time = .5):
    time.sleep(sleep_time)
    #TODO: POTENTIALLY UNCOMMENT BELOW TEST OUTPUT PRINT STATEMENTS
    print("Attempting to grab data about", name)
    # No additional text = Success
    try:    
        done = get_gamedata(name)
    #TODO: trying to think of possibility get_gamedata fails... maybe add a better fail return?
    except:
        try:
            # in this case, possibly the name wasn't within the first 5 results, so trying more
            print("RETRY RETRY:", name)
            done = get_gamedata(name, 30)
        except:
            # on a fail, I will return None and I will have to make this into an empty row later
            print("\tFAILED RETRY")
            done = None
    return done

# testing on a small subset (to preserve time) of the table to make sure it works
# small_df = gdf.head()  # more reproducable
small_df = gdf.sample(5)  # better to tell if it works consistently
# small_df

small_df_result = [single_get(a_game) for a_game in small_df["Name"]]
small_df_result
# Out:
# Attempting to grab data about Sherlock Holmes: Crimes and Punishments
# Attempting to grab data about Yoku’s Island Express
# RETRY RETRY: Yoku’s Island Express
# 	FAILED RETRY
# Attempting to grab data about Torchlight II
# Attempting to grab data about Railway Empire
# Attempting to grab data about What Remains of Edith Finch
# [{'id': 'afadb715390a4593acdca79dae94b60a',
#   'descr': 'Become the most celebrated detective of all time: Sherlock Holmes! Use your impressive talents as a detective to solve six thrilling and varied cases.',
#   'namespace': '23f3da2016b94461a7bd7e2eb46aa0f9',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '21894'}, {'id': '9547'}, {'id': '1117'}]},
#  None,
#  {'id': '9ca2b214a7b0477cb57fb0975f50043c',
#   'descr': 'Torchlight II is filled to the brim with randomized levels, enemies and loot. Capturing all the flavor and excitement of the original, Torchlight II expands the world and adds features players wanted most, including online and LAN multiplayer.',
#   'namespace': '8432511ef63b489b843d21ff486a0355',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '21122'},
#    {'id': '1188'},
#    {'id': '21894'},
#    {'id': '21127'},
#    {'id': '9547'},
#    {'id': '1264'},
#    {'id': '1265'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1367'},
#    {'id': '1336'},
#    {'id': '21147'},
#    {'id': '21149'},
#    {'id': '10719'},
#    {'id': '21119'}]},
#  {'id': 'f5f7971517134ed488fd51974563f5f5',
#   'descr': 'In Railway Empire, you will create an elaborate and wide-ranging rail network, purchase over 40 different trains modelled in extraordinary detail, and buy or build railway stations, factories and attractions to keep your network ahead of the competition.',
#   'namespace': '93b333eb973b45b582f3bdf68dfc1dc9',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1188'},
#    {'id': '21894'},
#    {'id': '21127'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1393'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '21146'},
#    {'id': '1115'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': 'b1f4888a7c9b4449b6bfbace4de24a9c',
#   'descr': "What Remains of Edith Finch is a collection of strange tales about a family in Washington state. As Edith, you’ll explore the colossal Finch house, searching for stories as she explores her family history and tries to figure out why she's the last one in her family left alive....",
#   'namespace': 'badger',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1298'},
#    {'id': '1395'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1294'}]}]

# %%
# Investigating some worrisome errors

# ff = gdf["Name"][3]
# get_gamedata("The Bridge")
# get_gamedata(ff)
api.fetch_store_games(count = 30, keywords = "Yoku’s Island Express") 

# Not working! Reason?
# AGE RESTRICTION, DUNNO HOW TO CIRCUMVENT
# perhaps I need to be logged in but wrapper doesn't have credential options
# fallback option: do Selenium after all (perhaps only for the failed, empty rows?)
# Out:
# {'data': {'Catalog': {'searchStore': {'elements': [],
#     'paging': {'count': 30, 'total': 0}}}},
#  'extensions': {}}

# %%
# CAUTION: TAKES A LONG TIME TO RUN! OUTPUTS A LOT TOO!
# This goes through the entire table and uses the API for all almost 500 games
# could add optional argument sleep_time for other than .5 if I want to though
big_df = [single_get(a_game) for a_game in gdf["Name"]]  # pulls all strings from "Name" column in gdf, same order
big_df
# Out:
# Attempting to grab data about The Bridge
# RETRY RETRY: The Bridge
# Attempting to grab data about Deus Ex: Mankind Divided
# RETRY RETRY: Deus Ex: Mankind Divided
# 	FAILED RETRY
# Attempting to grab data about Astro Duel 2
# Attempting to grab data about Aerial_Knight’s Never Yield
# RETRY RETRY: Aerial_Knight’s Never Yield
# 	FAILED RETRY
# Attempting to grab data about Super Meat Boy Forever
# Attempting to grab data about Dakar Desert Rally
# Attempting to grab data about Lost Castle
# Attempting to grab data about Doki Doki Literature Club Plus!
# Attempting to grab data about Doors: Paradox
# RETRY RETRY: Doors: Paradox
# 	FAILED RETRY
# Attempting to grab data about Infinifactory
# Attempting to grab data about Love
# RETRY RETRY: Love
# 	FAILED RETRY
# Attempting to grab data about Sail Forth
# Attempting to grab data about Marvel’s Guardians of the Galaxy
# RETRY RETRY: Marvel’s Guardians of the Galaxy
# 	FAILED RETRY
# Attempting to grab data about A Plague Tale: Innocence
# Attempting to grab data about 20 Minutes Till Dawn
# Attempting to grab data about Escape Academy
# Attempting to grab data about Ghostrunner
# Attempting to grab data about Saints Row
# Attempting to grab data about Snakebird Complete
# Attempting to grab data about Cat Quest
# RETRY RETRY: Cat Quest
# Attempting to grab data about Cursed to Golf
# Attempting to grab data about Human Resource Machine
# Attempting to grab data about The Outer Worlds: Spacer’s Choice Edition
# RETRY RETRY: The Outer Worlds: Spacer’s Choice Edition
# 	FAILED RETRY
# Attempting to grab data about Ghostwire: Tokyo
# Attempting to grab data about Fallout 3: Game of the Year Edition
# Attempting to grab data about Art of Rally
# Attempting to grab data about Melvor Idle
# Attempting to grab data about DNF Duel
# Attempting to grab data about Destiny 2: Legacy Collection
# RETRY RETRY: Destiny 2: Legacy Collection
# 	FAILED RETRY
# Attempting to grab data about Predecessor
# Attempting to grab data about GigaBash
# Attempting to grab data about Mighty Fight Federation
# Attempting to grab data about Jitsu Squad
# Attempting to grab data about Deliver Us Mars
# Attempting to grab data about Surviving the Aftermath
# Attempting to grab data about Earthlock
# RETRY RETRY: Earthlock
# 	FAILED RETRY
# Attempting to grab data about Golden Light
# Attempting to grab data about Turnip Boy Commits Tax Evasion
# Attempting to grab data about The Evil Within 2
# Attempting to grab data about Tandem: A Tale of Shadows
# Attempting to grab data about The Evil Within
# Attempting to grab data about Eternal Threads
# Attempting to grab data about Q.U.B.E. 2 Season Pass
# RETRY RETRY: Q.U.B.E. 2 Season Pass
# 	FAILED RETRY
# Attempting to grab data about Q.U.B.E. 2
# Attempting to grab data about Q.U.B.E. 10th Anniversary
# Attempting to grab data about Blazing Sails
# Attempting to grab data about Godlike Burger
# Attempting to grab data about Soulstice
# Attempting to grab data about Model Builder
# Attempting to grab data about The Forest Quartet
# Attempting to grab data about Out of Line
# Attempting to grab data about 911 Operator
# Attempting to grab data about Spelldrifter
# Attempting to grab data about Cave Story+
# Attempting to grab data about Homeworld: Deserts of Kharak
# Attempting to grab data about Dodo Peak
# Attempting to grab data about Black Book
# Attempting to grab data about Orwell: Keeping an Eye on You
# Attempting to grab data about Europa Universalis IV
# Attempting to grab data about Loop Hero
# Attempting to grab data about Bloons TD 6
# Attempting to grab data about Severed Steel
# Attempting to grab data about Homeworld Remastered Collection
# Attempting to grab data about The Elder Scrolls Online
# Attempting to grab data about Murder by Numbers
# Attempting to grab data about Train Valley 2
# Attempting to grab data about Grime
# RETRY RETRY: Grime
# 	FAILED RETRY
# Attempting to grab data about The Dungeon of Naheulbeuk: The Amulet of Chaos
# RETRY RETRY: The Dungeon of Naheulbeuk: The Amulet of Chaos
# 	FAILED RETRY
# Attempting to grab data about theHunter: Call of the Wild
# RETRY RETRY: theHunter: Call of the Wild
# 	FAILED RETRY
# Attempting to grab data about Idle Champions of the Forgotten Realms
# Attempting to grab data about Guacamelee! 2
# Attempting to grab data about Guacamelee! Super Turbo Championship Edition
# Attempting to grab data about Payday 2
# RETRY RETRY: Payday 2
# 	FAILED RETRY
# Attempting to grab data about Midnight Ghost Hunt
# Attempting to grab data about Fallout: New Vegas Ultimate Edition
# RETRY RETRY: Fallout: New Vegas Ultimate Edition
# 	FAILED RETRY
# Attempting to grab data about Death Stranding
# Attempting to grab data about The Sims 4 The Daring Lifestyle Bundle
# RETRY RETRY: The Sims 4 The Daring Lifestyle Bundle
# 	FAILED RETRY
# Attempting to grab data about Kao the Kangaroo
# Attempting to grab data about Horizon Chase Turbo
# Attempting to grab data about Against All Odds
# Attempting to grab data about Poker Club
# Attempting to grab data about Breathedge
# Attempting to grab data about Never Alone (Kisima Ingitchuna)
# Attempting to grab data about Beyond Blue
# Attempting to grab data about Second Extinction
# RETRY RETRY: Second Extinction
# 	FAILED RETRY
# Attempting to grab data about Mordhau
# RETRY RETRY: Mordhau
# 	FAILED RETRY
# Attempting to grab data about Dying Light: The Following – Enhanced Edition
# RETRY RETRY: Dying Light: The Following – Enhanced Edition
# 	FAILED RETRY
# Attempting to grab data about shapez
# Attempting to grab data about Tunche
# Attempting to grab data about The Silent Age
# Attempting to grab data about World of Warships – Starter Pack: Ishizuchi
# RETRY RETRY: World of Warships – Starter Pack: Ishizuchi
# 	FAILED RETRY
# Attempting to grab data about Chess Ultra
# Attempting to grab data about Warhammer 40,000: Gladius – Relics of War
# RETRY RETRY: Warhammer 40,000: Gladius – Relics of War
# 	FAILED RETRY
# Attempting to grab data about Call of the Sea
# Attempting to grab data about Rise of Industry
# Attempting to grab data about Duskers
# Attempting to grab data about Warpips
# Attempting to grab data about Recipe for Disaster
# Attempting to grab data about Dishonored: Death of the Outsider
# RETRY RETRY: Dishonored: Death of the Outsider
# 	FAILED RETRY
# Attempting to grab data about City of Gangsters
# Attempting to grab data about Hell Is Others
# RETRY RETRY: Hell Is Others
# 	FAILED RETRY
# Attempting to grab data about Adios
# Attempting to grab data about Epistory: Typing Chronicles
# RETRY RETRY: Epistory: Typing Chronicles
# 	FAILED RETRY
# Attempting to grab data about Gamedec: Definitive Edition
# RETRY RETRY: Gamedec: Definitive Edition
# 	FAILED RETRY
# Attempting to grab data about First Class Trouble
# Attempting to grab data about Divine Knockout
# Attempting to grab data about Shadow Tactics: Aiko’s Choice
# RETRY RETRY: Shadow Tactics: Aiko’s Choice
# 	FAILED RETRY
# Attempting to grab data about Kerbal Space Program
# Attempting to grab data about Eximius: Seize the Frontline
# Attempting to grab data about Dishonored: Definitive Edition
# RETRY RETRY: Dishonored: Definitive Edition
# 	FAILED RETRY
# Attempting to grab data about Mortal Shell
# Attempting to grab data about Severed Steel
# Attempting to grab data about F.I.S.T.: Forged in Shadow Torch
# RETRY RETRY: F.I.S.T.: Forged in Shadow Torch
# 	FAILED RETRY
# Attempting to grab data about Death Stranding
# Attempting to grab data about Metro: Last Light Redux
# Attempting to grab data about Encased
# Attempting to grab data about Fallout Tactics: Brotherhood of Steel
# Attempting to grab data about Fallout 2: A Post Nuclear Role Playing Game
# Attempting to grab data about Fallout: A Post Nuclear Role Playing Game
# Attempting to grab data about LEGO Builder’s Journey
# RETRY RETRY: LEGO Builder’s Journey
# 	FAILED RETRY
# Attempting to grab data about Wolfenstein: The New Order
# Attempting to grab data about Them’s Fightin’ Herds
# RETRY RETRY: Them’s Fightin’ Herds
# 	FAILED RETRY
# Attempting to grab data about Sable
# RETRY RETRY: Sable
# Attempting to grab data about Costume Quest 2
# Attempting to grab data about Horizon Chase Turbo
# Attempting to grab data about Bloons TD 6
# Attempting to grab data about Wildcat Gun Machine
# Attempting to grab data about Saints Row IV: Re-Elected
# RETRY RETRY: Saints Row IV: Re-Elected
# 	FAILED RETRY
# Attempting to grab data about RPG in a Box
# RETRY RETRY: RPG in a Box
# 	FAILED RETRY
# Attempting to grab data about Fort Triumph
# Attempting to grab data about Star Wars: Squadrons
# RETRY RETRY: Star Wars: Squadrons
# 	FAILED RETRY
# Attempting to grab data about Evil Dead: The Game
# Attempting to grab data about Dark Deity
# Attempting to grab data about Epic Cheerleader Pack
# RETRY RETRY: Epic Cheerleader Pack
# 	FAILED RETRY
# Attempting to grab data about Shadow Tactics: Blades of the Shogun
# Attempting to grab data about Alba: A Wildlife Adventure
# RETRY RETRY: Alba: A Wildlife Adventure
# 	FAILED RETRY
# Attempting to grab data about Rising Storm 2: Vietnam
# Attempting to grab data about Filament
# Attempting to grab data about Warhammer 40,000: Mechanicus
# RETRY RETRY: Warhammer 40,000: Mechanicus
# 	FAILED RETRY
# Attempting to grab data about Saturnalia
# Attempting to grab data about Fallout 3: Game of the Year Edition
# Attempting to grab data about Evoland Legendary Edition
# Attempting to grab data about ToeJam & Earl: Back in the Groove!
# Attempting to grab data about Darkwood
# Attempting to grab data about Slain: Back from Hell
# RETRY RETRY: Slain: Back from Hell
# 	FAILED RETRY
# Attempting to grab data about Rising Hell
# Attempting to grab data about The Drone Racing League
# RETRY RETRY: The Drone Racing League
# 	FAILED RETRY
# Attempting to grab data about Runbow
# Attempting to grab data about Gloomhaven
# Attempting to grab data about Ark: Survival Evolved
# RETRY RETRY: Ark: Survival Evolved
# 	FAILED RETRY
# Attempting to grab data about The Captain
# RETRY RETRY: The Captain
# Attempting to grab data about Spirit of the North
# Attempting to grab data about Realm Royale Reforged – Epic Launch Bundle
# RETRY RETRY: Realm Royale Reforged – Epic Launch Bundle
# 	FAILED RETRY
# Attempting to grab data about Hundred Days – Winemaking Simulator
# RETRY RETRY: Hundred Days – Winemaking Simulator
# 	FAILED RETRY
# Attempting to grab data about Submerged: Hidden Depths
# Attempting to grab data about Shadow of the Tomb Raider: Definitive Edition
# Attempting to grab data about Knockout City
# RETRY RETRY: Knockout City
# 	FAILED RETRY
# Attempting to grab data about Ring of Pain
# Attempting to grab data about Destiny 2: Bungie 30th Anniversary Pack
# RETRY RETRY: Destiny 2: Bungie 30th Anniversary Pack
# 	FAILED RETRY
# Attempting to grab data about Rumbleverse – Boom Boxer Content Pack
# RETRY RETRY: Rumbleverse – Boom Boxer Content Pack
# 	FAILED RETRY
# Attempting to grab data about Doom 64
# RETRY RETRY: Doom 64
# 	FAILED RETRY
# Attempting to grab data about Cook, Serve, Delicious! 3?!
# Attempting to grab data about Unrailed!
# Attempting to grab data about Lawn Mowing Simulator
# Attempting to grab data about Tannenberg
# Attempting to grab data about Shop Titans
# Attempting to grab data about Wonder Boy: The Dragon’s Trap
# RETRY RETRY: Wonder Boy: The Dragon’s Trap
# 	FAILED RETRY
# Attempting to grab data about Killing Floor 2
# Attempting to grab data about Ancient Enemy
# Attempting to grab data about Iratus: Lord of the Dead
# Attempting to grab data about Hood: Outlaws & Legends
# Attempting to grab data about Geneforge 1 – Mutagen
# RETRY RETRY: Geneforge 1 – Mutagen
# 	FAILED RETRY
# Attempting to grab data about Car Mechanic Simulator 2018
# Attempting to grab data about A Game of Thrones: The Board Game Digital Edition
# RETRY RETRY: A Game of Thrones: The Board Game Digital Edition
# 	FAILED RETRY
# Attempting to grab data about Supraland
# Attempting to grab data about Maneater
# Attempting to grab data about Wolfenstein: The New Order
# Attempting to grab data about BioShock Infinite: Complete Edition
# Attempting to grab data about BioShock 2 Remastered
# Attempting to grab data about BioShock Remastered
# Attempting to grab data about Borderlands 3
# Attempting to grab data about Redout: Enhanced Edition
# Attempting to grab data about Prey
# Attempting to grab data about Jotun: Valhalla Edition
# Attempting to grab data about Terraforming Mars
# Attempting to grab data about Paradigm
# Attempting to grab data about Just Die Already
# Attempting to grab data about Riverbond
# Attempting to grab data about Amnesia: Rebirth
# Attempting to grab data about XCOM 2
# RETRY RETRY: XCOM 2
# 	FAILED RETRY
# Attempting to grab data about Insurmountable
# Attempting to grab data about Rogue Legacy
# Attempting to grab data about The Vanishing of Ethan Carter
# Attempting to grab data about Total War: Warhammer
# RETRY RETRY: Total War: Warhammer
# 	FAILED RETRY
# Attempting to grab data about City of Brass
# Attempting to grab data about Demon’s Tilt
# RETRY RETRY: Demon’s Tilt
# 	FAILED RETRY
# Attempting to grab data about In Sound Mind
# Attempting to grab data about Cities: Skylines
# Attempting to grab data about Centipede: Recharged
# Attempting to grab data about Black Widow: Recharged
# Attempting to grab data about Dauntless – Epic Slayer Kit
# RETRY RETRY: Dauntless – Epic Slayer Kit
# 	FAILED RETRY
# Attempting to grab data about Cris Tales
# Attempting to grab data about Brothers: A Tale of Two Sons
# RETRY RETRY: Brothers: A Tale of Two Sons
# 	FAILED RETRY
# Attempting to grab data about Windbound
# Attempting to grab data about Yooka-Laylee and the Impossible Lair
# Attempting to grab data about Daemon X Machina
# RETRY RETRY: Daemon X Machina
# 	FAILED RETRY
# Attempting to grab data about Relicta
# Attempting to grab data about Galactic Civilizations III
# Attempting to grab data about Gods Will Fall
# Attempting to grab data about Shadow of the Tomb Raider: Definitive Edition
# Attempting to grab data about Rise of the Tomb Raider: 20 Year Celebration
# Attempting to grab data about Tomb Raider Game of the Year Edition
# RETRY RETRY: Tomb Raider Game of the Year Edition
# 	FAILED RETRY
# Attempting to grab data about Salt and Sanctuary
# Attempting to grab data about Moving Out
# Attempting to grab data about Mages of Mystralia
# Attempting to grab data about Control
# RETRY RETRY: Control
# 	FAILED RETRY
# Attempting to grab data about Prey
# Attempting to grab data about Pathfinder: Kingmaker
# RETRY RETRY: Pathfinder: Kingmaker
# 	FAILED RETRY
# Attempting to grab data about Vampyr
# Attempting to grab data about Mutant Year Zero: Road to Eden
# Attempting to grab data about Second Extinction
# RETRY RETRY: Second Extinction
# 	FAILED RETRY
# Attempting to grab data about Loop Hero
# Attempting to grab data about The Vanishing of Ethan Carter
# Attempting to grab data about Remnant: From the Ashes
# Attempting to grab data about Neon Abyss
# Attempting to grab data about Shenmue III
# Attempting to grab data about Prison Architect
# Attempting to grab data about Godfall Challenger Edition
# RETRY RETRY: Godfall Challenger Edition
# 	FAILED RETRY
# Attempting to grab data about while True: learn()
# Attempting to grab data about Dead by Daylight
# Attempting to grab data about Antstream – Epic Welcome Pack
# RETRY RETRY: Antstream – Epic Welcome Pack
# 	FAILED RETRY
# Attempting to grab data about theHunter: Call of the Wild
# RETRY RETRY: theHunter: Call of the Wild
# 	FAILED RETRY
# Attempting to grab data about Guild of Dungeoneering
# RETRY RETRY: Guild of Dungeoneering
# 	FAILED RETRY
# Attempting to grab data about Kid A Mnesia Exhibition
# RETRY RETRY: Kid A Mnesia Exhibition
# 	FAILED RETRY
# Attempting to grab data about Never Alone
# Attempting to grab data about Rogue Company Season Four Epic Pack
# RETRY RETRY: Rogue Company Season Four Epic Pack
# 	FAILED RETRY
# Attempting to grab data about Tiny Tina’s Assault on Dragon Keep
# RETRY RETRY: Tiny Tina’s Assault on Dragon Keep
# 	FAILED RETRY
# Attempting to grab data about Aven Colony
# Attempting to grab data about DARQ: Complete Edition
# Attempting to grab data about Among the Sleep – Enhanced Edition
# RETRY RETRY: Among the Sleep – Enhanced Edition
# 	FAILED RETRY
# Attempting to grab data about Stubbs the Zombie in Rebel Without a Pulse
# Attempting to grab data about Paladins Epic Pack
# Attempting to grab data about PC Building Simulator
# Attempting to grab data about Europa Universalis IV
# Attempting to grab data about 2064: Read Only Memories
# Attempting to grab data about The Escapists
# Attempting to grab data about Tharsis
# Attempting to grab data about Speed Brawl
# Attempting to grab data about Sheltered
# Attempting to grab data about Nioh: The Complete Edition
# Attempting to grab data about Yoku’s Island Express
# RETRY RETRY: Yoku’s Island Express
# 	FAILED RETRY
# Attempting to grab data about Automachef
# Attempting to grab data about Saints Row: The Third Remastered
# RETRY RETRY: Saints Row: The Third Remastered
# 	FAILED RETRY
# Attempting to grab data about Yooka-Laylee
# Attempting to grab data about Void Bastards
# Attempting to grab data about Rebel Galaxy
# Attempting to grab data about Minit
# Attempting to grab data about A Plague Tale: Innocence
# Attempting to grab data about Train Sim World 2
# RETRY RETRY: Train Sim World 2
# 	FAILED RETRY
# Attempting to grab data about Mothergunship
# Attempting to grab data about Verdun
# Attempting to grab data about Defense Grid: The Awakening
# Attempting to grab data about Obduction
# Attempting to grab data about Offworld Trading Company
# Attempting to grab data about Ironcast
# Attempting to grab data about Bridge Constructor: The Walking Dead
# Attempting to grab data about The Spectrum Retreat
# Attempting to grab data about Sonic Mania
# Attempting to grab data about Horizon Chase Turbo
# Attempting to grab data about Overcooked! 2
# Attempting to grab data about Hell Is Other Demons
# RETRY RETRY: Hell Is Other Demons
# 	FAILED RETRY
# Attempting to grab data about Control
# RETRY RETRY: Control
# 	FAILED RETRY
# Attempting to grab data about Frostpunk
# Attempting to grab data about Among Us
# Attempting to grab data about NBA 2K21
# RETRY RETRY: NBA 2K21
# 	FAILED RETRY
# Attempting to grab data about The Lion’s Song
# RETRY RETRY: The Lion’s Song
# 	FAILED RETRY
# Attempting to grab data about Pine
# Attempting to grab data about World of Warships Exclusive Starter Pack
# RETRY RETRY: World of Warships Exclusive Starter Pack
# 	FAILED RETRY
# Attempting to grab data about Idle Champions of the Forgotten Realms
# Attempting to grab data about Alien: Isolation
# Attempting to grab data about Hand of Fate 2
# Attempting to grab data about Deponia: The Complete Journey
# Attempting to grab data about Ken Follett’s The Pillars of the Earth
# RETRY RETRY: Ken Follett’s The Pillars of the Earth
# 	FAILED RETRY
# Attempting to grab data about The First Tree
# Attempting to grab data about 3 out of 10: Season Two
# Attempting to grab data about Tales of the Neon Sea
# Attempting to grab data about Creature in the Well
# Attempting to grab data about The Fall
# RETRY RETRY: The Fall
# 	FAILED RETRY
# Attempting to grab data about Surviving Mars
# Attempting to grab data about Wargame: Red Dragon
# Attempting to grab data about Sunless Sea
# Attempting to grab data about Rage 2
# RETRY RETRY: Rage 2
# 	FAILED RETRY
# Attempting to grab data about Absolute Drift
# Attempting to grab data about Halcyon 6 Starbase Commander
# Attempting to grab data about Metro: Last Light Redux
# Attempting to grab data about For the King
# RETRY RETRY: For the King
# 	FAILED RETRY
# Attempting to grab data about Dandara: Trials of Fear Edition
# Attempting to grab data about Galactic Civilizations III
# Attempting to grab data about Star Wars Battlefront II: Celebration Edition
# RETRY RETRY: Star Wars Battlefront II: Celebration Edition
# 	FAILED RETRY
# Attempting to grab data about Crying Suns
# Attempting to grab data about Jurassic World Evolution
# Attempting to grab data about Torchlight II
# Attempting to grab data about Solitairica
# Attempting to grab data about Stranded Deep
# Attempting to grab data about Night in the Woods
# Attempting to grab data about My Time at Portia
# Attempting to grab data about Darkest Dungeon
# RETRY RETRY: Darkest Dungeon
# 	FAILED RETRY
# Attempting to grab data about Inside
# RETRY RETRY: Inside
# Attempting to grab data about Tropico 5
# Attempting to grab data about Metro 2033 Redux
# Attempting to grab data about Alien: Isolation
# Attempting to grab data about Defense Grid: The Awakening
# Attempting to grab data about The Long Dark
# RETRY RETRY: The Long Dark
# Attempting to grab data about Oddworld: New ‘n’ Tasty
# RETRY RETRY: Oddworld: New ‘n’ Tasty
# 	FAILED RETRY
# Attempting to grab data about Cities: Skylines
# Attempting to grab data about Pillars of Eternity: Definitive Edition
# RETRY RETRY: Pillars of Eternity: Definitive Edition
# 	FAILED RETRY
# Attempting to grab data about Tyranny: Gold Edition
# RETRY RETRY: Tyranny: Gold Edition
# 	FAILED RETRY
# Attempting to grab data about Cave Story+
# Attempting to grab data about MudRunner
# Attempting to grab data about Elite Dangerous
# Attempting to grab data about The World Next Door
# Attempting to grab data about The Textorcist: The Story of Ray Bibbia
# Attempting to grab data about Dungeons 3
# Attempting to grab data about Blair Witch
# Attempting to grab data about Ghostbusters: The Video Game Remastered
# Attempting to grab data about Layers of Fear 2
# Attempting to grab data about Costume Quest 2
# Attempting to grab data about Kingdom: New Lands
# RETRY RETRY: Kingdom: New Lands
# 	FAILED RETRY
# Attempting to grab data about Amnesia: A Machine for Pigs
# Attempting to grab data about Rising Storm 2: Vietnam
# Attempting to grab data about Abzû
# RETRY RETRY: Abzû
# 	FAILED RETRY
# Attempting to grab data about Pikuniku
# Attempting to grab data about RollerCoaster Tycoon 3: Complete Edition
# RETRY RETRY: RollerCoaster Tycoon 3: Complete Edition
# 	FAILED RETRY
# Attempting to grab data about Watch Dogs 2
# Attempting to grab data about Stick It to the Man!
# RETRY RETRY: Stick It to the Man!
# 	FAILED RETRY
# Attempting to grab data about Football Manager 2020
# RETRY RETRY: Football Manager 2020
# 	FAILED RETRY
# Attempting to grab data about Railway Empire
# Attempting to grab data about Where the Water Tastes like Wine
# RETRY RETRY: Where the Water Tastes like Wine
# 	FAILED RETRY
# Attempting to grab data about Into the Breach
# Attempting to grab data about Shadowrun Hong Kong – Extended Edition
# RETRY RETRY: Shadowrun Hong Kong – Extended Edition
# 	FAILED RETRY
# Attempting to grab data about Shadowrun: Dragonfall – Director’s Cut
# RETRY RETRY: Shadowrun: Dragonfall – Director’s Cut
# 	FAILED RETRY
# Attempting to grab data about Shadowrun Returns
# Attempting to grab data about Hitman
# RETRY RETRY: Hitman
# 	FAILED RETRY
# Attempting to grab data about God’s Trigger
# RETRY RETRY: God’s Trigger
# 	FAILED RETRY
# Attempting to grab data about Enter the Gungeon
# Attempting to grab data about Remnant: From the Ashes
# Attempting to grab data about The Alto Collection
# Attempting to grab data about A Total War Saga: TROY
# Attempting to grab data about Wilmot’s Warehouse
# RETRY RETRY: Wilmot’s Warehouse
# 	FAILED RETRY
# Attempting to grab data about 3 out of 10, EP 1
# RETRY RETRY: 3 out of 10, EP 1
# 	FAILED RETRY
# Attempting to grab data about 20XX
# Attempting to grab data about Superbrothers: Sword & Sworcery EP
# Attempting to grab data about Barony
# Attempting to grab data about Next Up Hero
# Attempting to grab data about Tacoma
# Attempting to grab data about Torchlight II
# Attempting to grab data about Lifeless Planet: Premier Edition
# Attempting to grab data about Killing Floor 2
# Attempting to grab data about The Escapists 2
# Attempting to grab data about Hue
# Attempting to grab data about Stranger Things 3: The Game
# RETRY RETRY: Stranger Things 3: The Game
# 	FAILED RETRY
# Attempting to grab data about AER Memories of Old
# Attempting to grab data about Pathway
# Attempting to grab data about Ark: Survival Evolved
# RETRY RETRY: Ark: Survival Evolved
# 	FAILED RETRY
# Attempting to grab data about Samurai Shodown NeoGeo Collection
# RETRY RETRY: Samurai Shodown NeoGeo Collection
# 	FAILED RETRY
# Attempting to grab data about Overcooked
# Attempting to grab data about Sludge Life
# Attempting to grab data about Borderlands: The Handsome Collection
# Attempting to grab data about Sid Meier’s Civilization VI
# RETRY RETRY: Sid Meier’s Civilization VI
# 	FAILED RETRY
# Attempting to grab data about Grand Theft Auto V: Premium Edition
# Attempting to grab data about Death Coming
# Attempting to grab data about Crashlands
# Attempting to grab data about Amnesia: The Dark Descent
# Attempting to grab data about For the King
# RETRY RETRY: For the King
# 	FAILED RETRY
# Attempting to grab data about Wheels of Aurelia
# Attempting to grab data about Just Cause 4
# Attempting to grab data about Close to the Sun
# Attempting to grab data about Sherlock Holmes: Crimes and Punishments
# Attempting to grab data about Drawful 2
# Attempting to grab data about Gone Home
# Attempting to grab data about Hob
# Attempting to grab data about Totally Reliable Delivery Service
# Attempting to grab data about World War Z
# RETRY RETRY: World War Z
# 	FAILED RETRY
# Attempting to grab data about Tormentor X Punisher
# RETRY RETRY: Tormentor X Punisher
# 	FAILED RETRY
# Attempting to grab data about Figment
# Attempting to grab data about The Stanley Parable
# Attempting to grab data about Watch Dogs
# Attempting to grab data about Mutazione
# Attempting to grab data about A Short Hike
# Attempting to grab data about Anodyne 2: Return to Dust
# Attempting to grab data about GoNNER
# Attempting to grab data about Offworld Trading Company
# Attempting to grab data about InnerSpace
# Attempting to grab data about Assassin’s Creed Syndicate
# RETRY RETRY: Assassin’s Creed Syndicate
# 	FAILED RETRY
# Attempting to grab data about Faeria
# Attempting to grab data about Aztez
# Attempting to grab data about Kingdom Come: Deliverance
# RETRY RETRY: Kingdom Come: Deliverance
# Attempting to grab data about Carcassonne
# Attempting to grab data about Ticket to Ride
# Attempting to grab data about Farming Simulator 19
# Attempting to grab data about The Bridge
# RETRY RETRY: The Bridge
# Attempting to grab data about Horace
# Attempting to grab data about Sundered: Eldritch Edition
# Attempting to grab data about Darksiders II
# RETRY RETRY: Darksiders II
# 	FAILED RETRY
# Attempting to grab data about Darksiders
# RETRY RETRY: Darksiders
# 	FAILED RETRY
# Attempting to grab data about Steep
# RETRY RETRY: Steep
# Attempting to grab data about Yooka-Laylee and the Impossible Lair
# Attempting to grab data about Hello Neighbor
# Attempting to grab data about The Talos Principle
# Attempting to grab data about Shadow Tactics: Blades of the Shogun
# Attempting to grab data about Hyper Light Drifter
# Attempting to grab data about FTL: Faster Than Light
# Attempting to grab data about Totally Accurate Battle Simulator
# Attempting to grab data about Celeste
# Attempting to grab data about Ape Out
# Attempting to grab data about Little Inferno
# Attempting to grab data about Superhot
# RETRY RETRY: Superhot
# 	FAILED RETRY
# Attempting to grab data about TowerFall Ascension
# Attempting to grab data about Into the Breach
# Attempting to grab data about The Escapists
# Attempting to grab data about The Wolf Among Us
# Attempting to grab data about Jotun: Valhalla Edition
# Attempting to grab data about Rayman Legends
# Attempting to grab data about Bad North
# Attempting to grab data about The Messenger
# Attempting to grab data about Nuclear Throne
# Attempting to grab data about Ruiner
# RETRY RETRY: Ruiner
# 	FAILED RETRY
# Attempting to grab data about Costume Quest
# Attempting to grab data about SOMA
# Attempting to grab data about Q.U.B.E. 2
# Attempting to grab data about Layers of Fear
# Attempting to grab data about Observer
# RETRY RETRY: Observer
# 	FAILED RETRY
# Attempting to grab data about Alan Wake’s American Nightmare
# Attempting to grab data about Surviving Mars
# Attempting to grab data about Minit
# Attempting to grab data about Everything
# RETRY RETRY: Everything
# Attempting to grab data about Metro 2033 Redux
# Attempting to grab data about Batman: Arkham Knight
# RETRY RETRY: Batman: Arkham Knight
# 	FAILED RETRY
# Attempting to grab data about Batman: Arkham City
# RETRY RETRY: Batman: Arkham City
# 	FAILED RETRY
# Attempting to grab data about Batman: Arkham Asylum
# RETRY RETRY: Batman: Arkham Asylum
# 	FAILED RETRY
# Attempting to grab data about LEGO Batman 3: Beyond Gotham
# RETRY RETRY: LEGO Batman 3: Beyond Gotham
# 	FAILED RETRY
# Attempting to grab data about LEGO Batman 2: DC Super Heroes
# RETRY RETRY: LEGO Batman 2: DC Super Heroes
# 	FAILED RETRY
# Attempting to grab data about LEGO Batman: The Videogame
# RETRY RETRY: LEGO Batman: The Videogame
# 	FAILED RETRY
# Attempting to grab data about Conarium
# Attempting to grab data about The End Is Nigh
# RETRY RETRY: The End Is Nigh
# 	FAILED RETRY
# Attempting to grab data about Abzû
# RETRY RETRY: Abzû
# 	FAILED RETRY
# Attempting to grab data about Celeste
# Attempting to grab data about Inside
# RETRY RETRY: Inside
# Attempting to grab data about Fez
# Attempting to grab data about Hyper Light Drifter
# Attempting to grab data about Mutant Year Zero: Road to Eden
# Attempting to grab data about GNOG
# Attempting to grab data about For Honor
# Attempting to grab data about Alan Wake
# Attempting to grab data about Moonlighter
# Attempting to grab data about This War of Mine
# RETRY RETRY: This War of Mine
# Attempting to grab data about Limbo
# Attempting to grab data about Torchlight
# Attempting to grab data about Overcooked
# Attempting to grab data about Last Day of June
# Attempting to grab data about Rebel Galaxy
# Attempting to grab data about Enter the Gungeon
# Attempting to grab data about Kingdom: New Lands
# RETRY RETRY: Kingdom: New Lands
# 	FAILED RETRY
# Attempting to grab data about City of Brass
# Attempting to grab data about RiME
# Attempting to grab data about Stories Untold
# Attempting to grab data about World of Goo
# RETRY RETRY: World of Goo
# Attempting to grab data about Transistor
# Attempting to grab data about The Witness
# RETRY RETRY: The Witness
# Attempting to grab data about Oxenfree
# Attempting to grab data about Slime Rancher
# Attempting to grab data about Thimbleweed Park
# Attempting to grab data about Axiom Verge
# Attempting to grab data about The Jackbox Party Pack
# Attempting to grab data about What Remains of Edith Finch
# Attempting to grab data about Super Meat Boy
# Attempting to grab data about Subnautica
# [{'id': '6b228a1ad940496dabc89ec6640107f3',
#   'descr': 'The Bridge',
#   'namespace': 'epic',
#   'orig_price': 999,
#   'fmt_orig_price': '$9.99',
#   'tags': [{'id': '1298'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '9549'}]},
#  None,
#  {'id': 'bc38eac0277d41ec955690e25779cb53',
#   'descr': 'Astro Duel 2 is a sci-fi combat game combining top-down space dog fights with up-close platforming action. Whether versus or co-op, battle through space and on foot at the same time! Strike within the fully-destructible arenas or just nuke ‘em from orbit.',
#   'namespace': '4a681a809a094e2c8dcc68353c68fed6',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '21894'},
#    {'id': '19847'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1264'},
#    {'id': '1299'},
#    {'id': '1110'},
#    {'id': '22776'},
#    {'id': '1370'},
#    {'id': '1151'},
#    {'id': '1183'},
#    {'id': '10719'}]},
#  None,
#  {'id': 'ef66029a1c0d467ea7755f6a88b4088c',
#   'descr': 'Super Meat Boy Forever',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'}, {'id': '1370'}, {'id': '9547'}, {'id': '1151'}]},
#  {'id': 'aca45f8a6b124590af039f97e148bd89',
#   'descr': 'Dakar Desert Rally is the biggest off-road rally racing adventure ever developed. Experience the speed and excitement of the largest rally race on the planet, featuring a wide variety of licensed vehicles from motorcycles, cars, trucks, quads and SSVs.',
#   'namespace': 'ac98aa34584648f2b71152e509191c1c',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1393'},
#    {'id': '21138'},
#    {'id': '1203'},
#    {'id': '1188'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1212'},
#    {'id': '21149'},
#    {'id': '21135'}]},
#  {'id': '186b5f89167f48fd94a9538ebfe214c6',
#   'descr': "Lost Castle is an action RPG beat'em up with roguelike elements and randomized dungeons for up to four players online and local!",
#   'namespace': 'ab29925a0a9a49598adba45d108ceb3e',
#   'orig_price': 999,
#   'fmt_orig_price': '$9.99',
#   'tags': [{'id': '1264'},
#    {'id': '1265'},
#    {'id': '21894'},
#    {'id': '1367'},
#    {'id': '1370'},
#    {'id': '1083'},
#    {'id': '9547'},
#    {'id': '9549'}]},
#  {'id': '76cd108ce4354545bd825e181262dbad',
#   'descr': 'Welcome to the club! Write poems for your crush and experience the terror of school romance in this critically-acclaimed psychological horror story.',
#   'namespace': '1311a5735ed844c0b3c47027cab321f0',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1218'},
#    {'id': '1367'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '21147'},
#    {'id': '10719'}]},
#  None,
#  {'id': 'e69075bc6dd84fa09b47af91b3ce6723',
#   'descr': 'Infinifactory is a sandbox puzzle game by Zachtronics, the creators of SpaceChem and Infiniminer. Build factories that assemble products for your alien overlords, and try not to die in the process',
#   'namespace': '1260f09c5ab842b9a645e14f085ed5af',
#   'orig_price': 2499,
#   'fmt_orig_price': '$24.99',
#   'tags': [{'id': '1298'},
#    {'id': '21138'},
#    {'id': '1188'},
#    {'id': '1370'},
#    {'id': '21146'},
#    {'id': '9547'},
#    {'id': '1294'},
#    {'id': '21150'},
#    {'id': '10719'}]},
#  None,
#  {'id': 'c819b6b40a034231ad64b8406f75814e',
#   'descr': 'Sail a fleet of customizable ships across an ocean whose ancient depths have swallowed the key to the mysterious past. Befriend fishfolk to expand your boat crews, take up arms against petulant pirates, and chart a course across an expansive watery world.',
#   'namespace': 'd93cf08971eb4920862a95870a051f81',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1381'},
#    {'id': '21141'},
#    {'id': '19847'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '21149'},
#    {'id': '9549'},
#    {'id': '1263'}]},
#  None,
#  {'id': '89e949b9176d4f04a5b2e6ca28655b21',
#   'descr': 'Follow the grim tale of young Amicia and her little brother Hugo, in a heartrending journey through the darkest hours of history. Hunted by Inquisition soldiers and surrounded by unstoppable swarms of rats, they will come to know and trust each other.',
#   'namespace': '71d19da3678943098859baa9c4c39f95',
#   'orig_price': 3999,
#   'fmt_orig_price': '$39.99',
#   'tags': [{'id': '1216'},
#    {'id': '21122'},
#    {'id': '1188'},
#    {'id': '21894'},
#    {'id': '21127'},
#    {'id': '9547'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '21146'},
#    {'id': '1117'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': '9758dccdbda54c1387f732d0d7d03b3b',
#   'descr': '20 Minutes Till Dawn is a survival roguelite where endless hordes of creatures lurk from the dark. Craft an array of overpowering builds and eradicate waves of Lovecraftian nightmares. Will you be able to survive the night?',
#   'namespace': 'ee9fad7056a94957b3a4d8c457000337',
#   'orig_price': 499,
#   'fmt_orig_price': '$4.99',
#   'tags': [{'id': '1216'},
#    {'id': '21122'},
#    {'id': '9547'},
#    {'id': '1263'},
#    {'id': '21137'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '1083'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': '224ed07084444c619cedc473c7cd1498',
#   'descr': 'Welcome to Escape Academy. Train to become the ultimate Escapist. Solve Puzzles. Hack Servers. Meet the Faculty. Brew the perfect cup of tea. Escape Rooms in single player or co-op with a friend - local or online!',
#   'namespace': '040baa2d100d465caf428c688cc3cdba',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1264'},
#    {'id': '1298'},
#    {'id': '1203'},
#    {'id': '21894'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '9549'},
#    {'id': '1294'}]},
#  {'id': '19b650f9a98a45b0bfe07674b51fa7a0',
#   'descr': 'Ghostrunner offers a unique single-player experience: fast-paced, violent combat, and an original setting that blends science fiction with post-apocalyptic themes. It tells the story of a world that has already ended and its inhabitants who fight to survive.',
#   'namespace': '95d0b9561be1464cb43bd029e94cf526',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1216'},
#    {'id': '21122'},
#    {'id': '21894'},
#    {'id': '21127'},
#    {'id': '9547'},
#    {'id': '1132'},
#    {'id': '21137'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1210'},
#    {'id': '1370'},
#    {'id': '21149'}]},
#  {'id': 'c8ae275e995940b0868d9f44e75d05d9',
#   'descr': 'Welcome to Santo Ileso, a vibrant fictional city in the American Southwest. In a world rife with crime, a group of young friends embark on their own criminal venture, as they rise to the top in their bid to become Self Made.',
#   'namespace': '0d23bb77ee2f45b7a571bde68caddb09',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1216'},
#    {'id': '21122'},
#    {'id': '1188'},
#    {'id': '21126'},
#    {'id': '21894'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1264'},
#    {'id': '21136'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21141'},
#    {'id': '1336'},
#    {'id': '1210'},
#    {'id': '1370'},
#    {'id': '1307'},
#    {'id': '1117'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': 'fddca2297b9a4354b59f8f83d4975c90',
#   'descr': 'Experience hit puzzle classic Snakebird and Snakebird Primer in Snakebird Complete, a brand new package that reunites both beloved titles into one seamless experience. Now with a hint system!',
#   'namespace': 'efc30c2078a2499ab979d198255e2e4b',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1298'},
#    {'id': '21894'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '21150'},
#    {'id': '10719'}]},
#  {'id': '2da36fbed1b34d1997e5ffb1f8efdeb6',
#   'descr': "The multi award-winning Action RPG. Cat Quest's loot-fuelled cat-venture is as beautifully crafted, as its combat and magic are ultra-satisfying. Universally adored by critics - it'll have you purring for joy!",
#   'namespace': 'c986e75258a146fba03a920dba852ca9',
#   'orig_price': 1299,
#   'fmt_orig_price': '$12.99',
#   'tags': [{'id': '1296'},
#    {'id': '21894'},
#    {'id': '1367'},
#    {'id': '19847'},
#    {'id': '1336'},
#    {'id': '1370'},
#    {'id': '21147'},
#    {'id': '9547'},
#    {'id': '9549'}]},
#  {'id': 'cc8016226a1a4bca9208e071073ad788',
#   'descr': 'Cursed to Golf is a golf-like adventure where every shot counts. Players are tasked with making it out of Golf Purgatory to become a Golfing Legend.',
#   'namespace': '2cdc5a2758a6445d8d4f399ecb469aaf',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1283'},
#    {'id': '21109'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1263'}]},
#  {'id': '6a76c942e36e46c4ab566a21b5f46461',
#   'descr': 'Human Resource Machine',
#   'namespace': 'epic',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1298'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '1102'},
#    {'id': '1263'}]},
#  None,
#  {'id': '53a6356d1f4945e58d8c8e9f511c3c9d',
#   'descr': "Tokyo's population has vanished, and deadly supernatural forces prowl the streets. Use an arsenal of elemental abilities to unravel the truth behind the disappearance and save Tokyo. ",
#   'namespace': 'a93cd6111251461c953776a0c4ea4d80',
#   'orig_price': 5999,
#   'fmt_orig_price': '$59.99',
#   'tags': [{'id': '1216'},
#    {'id': '21122'},
#    {'id': '1188'},
#    {'id': '21894'},
#    {'id': '21127'},
#    {'id': '9547'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1336'},
#    {'id': '1370'},
#    {'id': '1117'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': 'd6f01b1827c64ed388191ae507fe7c1b',
#   'descr': 'Prepare for the Future™\nExperience the most acclaimed game of 2008 like never before with Fallout 3: Game of the Year Edition. Create a character of your choosing and descend into a post-apocalyptic world where every minute is a fight for survival',
#   'namespace': 'fa702d34a37248ba98fb17f680c085e3',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '21122'},
#    {'id': '1188'},
#    {'id': '21894'},
#    {'id': '21127'},
#    {'id': '9547'},
#    {'id': '21137'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1367'},
#    {'id': '1370'},
#    {'id': '1307'},
#    {'id': '21147'},
#    {'id': '1117'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': '8a2dd95a9fe04bdebde02b46a8f41aed',
#   'descr': 'art of rally is a stylized experience inspired by the golden era of rally from the creator of Absolute Drift  Race across the world through colorful and stylized environments in top-down view.  Will you master the art of rally?',
#   'namespace': '4751c4f6a96547209a33831d847d2810',
#   'orig_price': 2499,
#   'fmt_orig_price': '$24.99',
#   'tags': [{'id': '21121'},
#    {'id': '1188'},
#    {'id': '21125'},
#    {'id': '21894'},
#    {'id': '19847'},
#    {'id': '21129'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1400'},
#    {'id': '1212'},
#    {'id': '21149'},
#    {'id': '10719'}]},
#  {'id': '99f665baf7ab4d5597504a2ff46b3edc',
#   'descr': 'Inspired by RuneScape, Melvor Idle takes the core of what makes an adventure game so addictive and strips it down to its purest form! This is a feature-rich, idle/incremental game combining a distinctly familiar feel with a fresh gameplay experience.',
#   'namespace': '207c42b0325d40ebb0414041dac29b19',
#   'orig_price': 999,
#   'fmt_orig_price': '$9.99',
#   'tags': [{'id': '1188'},
#    {'id': '21127'},
#    {'id': '9547'},
#    {'id': '1263'},
#    {'id': '21137'},
#    {'id': '21138'},
#    {'id': '21141'},
#    {'id': '1367'},
#    {'id': '1370'},
#    {'id': '1115'},
#    {'id': '21147'},
#    {'id': '21149'},
#    {'id': '10719'},
#    {'id': '21119'}]},
#  {'id': '9f314276c254423bb9b145480b5b150b',
#   'descr': 'Action fighting at its extreme! One of the most popular and widely played RPGs in the world, Dungeon and Fighter is now back as a 2.5D action fighting game. Choose from 16 charming characters, each with their distinct skills and personalities.',
#   'namespace': '3eb832eb6d9f4496818a0b0d667420c0',
#   'orig_price': 4999,
#   'fmt_orig_price': '$49.99',
#   'tags': [{'id': '1344'},
#    {'id': '29088'},
#    {'id': '21121'},
#    {'id': '21122'},
#    {'id': '1188'},
#    {'id': '21125'},
#    {'id': '19847'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  None,
#  {'id': 'a19138c05ca642d2a7fd73dcbadea7da',
#   'descr': 'Predecessor is the Paragon-fuelled, fast-paced action game that combines MOBA and FPS gameplay putting you at the heart of the fight with strategic choice, third person control and immersive action.  ',
#   'namespace': '85f0435aa88347d185dbcb147716609b',
#   'orig_price': 899,
#   'fmt_orig_price': '$8.99',
#   'tags': [{'id': '1216'},
#    {'id': '21122'},
#    {'id': '21138'},
#    {'id': '1203'},
#    {'id': '21139'},
#    {'id': '21125'},
#    {'id': '21141'},
#    {'id': '21129'},
#    {'id': '9547'},
#    {'id': '21149'},
#    {'id': '1310'}]},
#  {'id': '4a003a822ba54453b59c277f5bfc697f',
#   'descr': 'Claim your place as king among Titans!  GigaBash is a multiplayer arena brawler with gigantic film-inspired kaiju, larger than life heroes, earth-shattering special attacks and fully destructible environments.',
#   'namespace': '16fc138ed83846bc90d923fe0d87ad72',
#   'orig_price': 2499,
#   'fmt_orig_price': '$24.99',
#   'tags': [{'id': '1216'},
#    {'id': '1296'},
#    {'id': '1344'},
#    {'id': '1203'},
#    {'id': '21109'},
#    {'id': '1110'},
#    {'id': '21894'},
#    {'id': '19847'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1263'}]},
#  {'id': '61baaf316c8448e5b5c9ee80fe0b26f7',
#   'descr': 'Slam opponents into walls, launch them into the air & follow up with fast, high-flying attacks in this arena fighter. Choose from 14 characters with unique play styles. Face off in 1v1 matches, team up with other fighters or embrace the chaos of free-for-all.',
#   'namespace': '651d07f1eee8419e80eb2938f8f44cf0',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1344'},
#    {'id': '1203'},
#    {'id': '1299'},
#    {'id': '9547'},
#    {'id': '9549'}]},
#  {'id': '5526de3a3c35483da97b1b8ce970b360',
#   'descr': 'Jitsu Squad is a Marvel vs Capcom inspired 4 player co-op TAG TEAM beat ‘em up with epic character transformations and fast paced combat.',
#   'namespace': '6ef33a285bf5426d852762aecc95c826',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1264'},
#    {'id': '1344'},
#    {'id': '1203'},
#    {'id': '21129'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1263'}]},
#  {'id': '34c8b5efd29f48209928d74752584426',
#   'descr': 'Deliver Us Mars is an atmospheric sci-fi adventure taking you on a suspense-fuelled, high-stakes mission to recover the ARK colony ships stolen by the mysterious Outward.',
#   'namespace': '53ec6d9f552241549c4d8aa1a42bcb3b',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1216'},
#    {'id': '19847'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '1263'}]},
#  {'id': 'eb081710a4b64e068c8881a138d9de3f',
#   'descr': 'Surviving the Aftermath',
#   'namespace': 'epic',
#   'orig_price': 2499,
#   'fmt_orig_price': '$24.99',
#   'tags': [{'id': '1393'},
#    {'id': '1146'},
#    {'id': '1370'},
#    {'id': '1115'},
#    {'id': '9547'}]},
#  None,
#  {'id': 'f787056536bf43298e39305a0c5c20c8',
#   'descr': 'Eat weapons, be scared and question your own mind in this Survival-Horror FPS Prop Hunt Roguelike about meat. Walls are watching you!',
#   'namespace': 'ca05bd340e84436ebea4a0c0ca55befa',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '19847'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1084'},
#    {'id': '1198'}]},
#  {'id': 'e0282b701ea04c42ac1b5a55c1a3bfde',
#   'descr': 'Play as an adorable yet trouble-making turnip. Avoid paying taxes, solve plantastic puzzles, harvest crops and battle massive beasts all in a journey to tear down a corrupt vegetable government!',
#   'namespace': '80be39e522204fd0942916d73234d044',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1296'},
#    {'id': '1336'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1263'}]},
#  {'id': '77693e5298d94911a0edd2492203d9ea',
#   'descr': 'To save his daughter, Detective Sebastian Castellanos returns to a world of nightmares in The Evil Within 2. \n \nFight for your life inside a terrifying reality using weapons, traps and stealth in this survival horror follow-up from Tango Gameworks.',
#   'namespace': '5891aa5c4c6f4aabbf555a679e02cfb9',
#   'orig_price': 3999,
#   'fmt_orig_price': '$39.99',
#   'tags': [{'id': '1218'},
#    {'id': '21122'},
#    {'id': '19847'},
#    {'id': '21127'},
#    {'id': '9547'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1080'},
#    {'id': '1210'},
#    {'id': '1370'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  {'id': '9142916d80f54720b01f8f62b21014be',
#   'descr': 'Tandem : A Tale of Shadows redefines the puzzle platformer genre with a unique gameplay and exceptional aesthetics. Help Emma and the teddy bear Fenton solve the mystery of the disappearance of the famous magician Thomas Kane.',
#   'namespace': 'd1a3ff292b2f4ee289a83d7a91ae3458',
#   'orig_price': 999,
#   'fmt_orig_price': '$9.99',
#   'tags': [{'id': '1298'},
#    {'id': '1336'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1151'}]},
#  {'id': '087155540ecc47239c98c1265b40ba99',
#   'descr': 'Developed by Tango Gameworks and directed by Resident Evil series creator Shinji Mikami, The Evil Within embodies pure survival horror. \n\nAs Detective Sebastian Castellanos, fight for survival with limited resources in a twisted world of nightmares.',
#   'namespace': 'd602fd70876141ba9bf4d54809c423d1',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1218'},
#    {'id': '21122'},
#    {'id': '19847'},
#    {'id': '21127'},
#    {'id': '21129'},
#    {'id': '9547'},
#    {'id': '21137'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1080'},
#    {'id': '1210'},
# ...
#  {'id': '52e1d1095dad49799b3e95cc591d29f6',
#   'descr': 'SOMA',
#   'namespace': 'epic',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1218'},
#    {'id': '1395'},
#    {'id': '1080'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '9549'}]},
#  {'id': '0c8b6d95ff2746648ccd356dbf941c12',
#   'descr': 'As stranded archaeologist, Amelia Cross, you must solve the puzzles of this mysterious world and find a way back home.',
#   'namespace': '4b5f1eb366dc45f0920d397c01b291ba',
#   'orig_price': 2499,
#   'fmt_orig_price': '$24.99',
#   'tags': [{'id': '1298'},
#    {'id': '19847'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '9549'},
#    {'id': '1294'}]},
#  {'id': '3bf85df66f784ee19ff1218fced5f386',
#   'descr': 'All stories must come to an end, even twisted and eerie ones. The canvas. The stage. The novel. This narrative-focused psychological horror experience is ready for its final brushstrokes, its curtain call, its final chapter. Are you ready to return and face your fears?',
#   'namespace': '9df61912ce644d8096412ba0f516759a',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1218'},
#    {'id': '21894'},
#    {'id': '19847'},
#    {'id': '1370'},
#    {'id': '9547'}]},
#  None,
#  {'id': 'da621d3c18154c82aedab85687fccdc6',
#   'descr': 'A thrilling new storyline, hordes of creepy enemies, serious firepower and beautiful Arizona locations, combined with a fun and challenging new game mode!',
#   'namespace': '4d2a12aff0484d699b1806ab104d259b',
#   'orig_price': 899,
#   'fmt_orig_price': '$8.99',
#   'tags': [{'id': '1216'},
#    {'id': '1218'},
#    {'id': '1210'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'}]},
#  {'id': '39516a5b66d04b75b25a810e593b0a97',
#   'descr': 'Surviving Mars is a sci-fi city builder all about colonizing Mars and surviving the process. Choose a space agency for resources and financial support before determining a location for your colony. Build domes and infrastructure, research new possibilities and utilize drones t...',
#   'namespace': 'd759128018124dcabb1fbee9bb28e178',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1188'},
#    {'id': '21894'},
#    {'id': '21127'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1080'},
#    {'id': '1146'},
#    {'id': '1370'},
#    {'id': '21146'},
#    {'id': '1115'},
#    {'id': '21149'},
#    {'id': '10719'},
#    {'id': '21119'}]},
#  {'id': 'c3bb66a9e2064fa580597cee86cbc1df',
#   'descr': 'Minit is a peculiar little adventure played sixty seconds at a time.',
#   'namespace': '43605e89e49d438485298819a7ef17b4',
#   'orig_price': 999,
#   'fmt_orig_price': '$9.99',
#   'tags': [{'id': '1298'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '1117'},
#    {'id': '9549'},
#    {'id': '10719'},
#    {'id': '1263'}]},
#  {'id': 'ca25cd054b29435c8e6e3794a27acbb2',
#   'descr': 'Everything',
#   'namespace': 'epic',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1296'},
#    {'id': '1393'},
#    {'id': '1370'},
#    {'id': '1307'},
#    {'id': '9547'}]},
#  {'id': '0dfa5a4398bb44c8b1ac34e5f248fab9',
#   'descr': 'In 2013, the world was devastated by an apocalyptic event, annihilating almost all mankind and turning the earth’s surface into a poisonous wasteland. A handful of survivors took refuge in the depths of the Moscow underground, and human civilization entered a new Dark Age.  Th...',
#   'namespace': 'petunia',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '21129'},
#    {'id': '9547'},
#    {'id': '1294'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1210'},
#    {'id': '1370'},
#    {'id': '21149'},
#    {'id': '21119'}]},
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  {'id': '3298096e41df45c4a42616542760365d',
#   'descr': 'Conarium',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1218'},
#    {'id': '1298'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1263'}]},
#  None,
#  None,
#  {'id': '544c18ccadf8466691d8f2a335721b14',
#   'descr': 'Help Madeline survive her inner demons on her journey to the top of Celeste Mountain, in this super-tight platformer from the creators of TowerFall. Brave hundreds of hand-crafted challenges, uncover devious secrets, and piece together the mystery of the mountain.',
#   'namespace': 'b671fbc7be424e888c9346a9a6d3d9db',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1188'},
#    {'id': '21894'},
#    {'id': '21129'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '21134'},
#    {'id': '1263'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '21149'},
#    {'id': '10719'},
#    {'id': '1151'}]},
#  {'id': '513fe4b9afb54c18bc88b1b6dd6ca8d8',
#   'descr': 'Inside',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1298'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '9549'},
#    {'id': '1263'}]},
#  {'id': '442f123b4d884d8ca85236aa30b99a79',
#   'descr': 'Gomez is a 2D creature living in a 2D world. Or is he? When the existence of a mysterious 3rd dimension is revealed to him, Gomez is sent out on a journey that will take him to the very end of time and space. Use your ability to navigate 3D structures from 4 distinct classic 2...',
#   'namespace': '41f47fd0d3e248bc938a5815d6d64daa',
#   'orig_price': 999,
#   'fmt_orig_price': '$9.99',
#   'tags': [{'id': '1298'},
#    {'id': '21894'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '9549'},
#    {'id': '21150'},
#    {'id': '10719'},
#    {'id': '1151'}]},
#  {'id': '0d649bc9d1824294ad0e28fe8e411043',
#   'descr': 'Hyper Light Drifter',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1264'},
#    {'id': '1367'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'}]},
#  {'id': '9651fd57c8a34e81949aab28a084ced7',
#   'descr': 'Mankind has been eradicated by climate change, nuclear war, and pandemics. Will your team of mutants survive the Zone?  Mutant Year Zero: Road to Eden is a tactical adventure game combining turn-based combat with real-time exploration, story, stealth, and strategy.',
#   'namespace': '4756b80eb0f74d45b77922e54052cfed',
#   'orig_price': 3499,
#   'fmt_orig_price': '$34.99',
#   'tags': [{'id': '21122'},
#    {'id': '1188'},
#    {'id': '21894'},
#    {'id': '21129'},
#    {'id': '1386'},
#    {'id': '9547'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1367'},
#    {'id': '1370'},
#    {'id': '1115'},
#    {'id': '21147'},
#    {'id': '21149'}]},
#  {'id': '75804ef64d96446fb250a691fbd6654d',
#   'descr': 'GNOG',
#   'namespace': 'epic',
#   'orig_price': 999,
#   'fmt_orig_price': '$9.99',
#   'tags': [{'id': '1296'},
#    {'id': '1298'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1179'},
#    {'id': '9548'},
#    {'id': '9549'},
#    {'id': '1263'}]},
#  {'id': '1d2d37ffabdf4d97b10577499238b487',
#   'descr': 'For Honor',
#   'namespace': 'epic',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1216'},
#    {'id': '1344'},
#    {'id': '1203'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'}]},
#  {'id': '8e1c914755f44623be389ae027813f8c',
#   'descr': 'Alan Wake',
#   'namespace': 'epic',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1216'},
#    {'id': '1218'},
#    {'id': '1370'},
#    {'id': '1210'},
#    {'id': '9547'},
#    {'id': '9549'}]},
#  {'id': '8682f88d596749f1b1902f9f764638c5',
#   'descr': 'Moonlighter',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1367'},
#    {'id': '1258'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '1117'},
#    {'id': '9549'}]},
#  {'id': '589cbda0e6074cb2ae29df601f0407e3',
#   'descr': 'This War of Mine',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1218'},
#    {'id': '1080'},
#    {'id': '1370'},
#    {'id': '1115'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '9549'}]},
#  {'id': '49bdb24baa564f8c92848abe14112436',
#   'descr': 'Limbo is an award-winning indie adventure, critically acclaimed for its captivating puzzle design and immersive sound and visuals. Its dark, misty spaces and haunting narrative will stay with you forever.',
#   'namespace': '92053006068e4aa9b1ad413f72090f5e',
#   'orig_price': 999,
#   'fmt_orig_price': '$9.99',
#   'tags': [{'id': '1298'},
#    {'id': '21894'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1151'},
#    {'id': '1263'}]},
#  {'id': '1ebfdccc11bd46dabdfc0fbb1490d13a',
#   'descr': 'Torchlight',
#   'namespace': 'epic',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1216'},
#    {'id': '1265'},
#    {'id': '1367'},
#    {'id': '1370'},
#    {'id': '9547'}]},
#  {'id': 'eed2eaea15864c52a7fe8c122dd6ce03',
#   'descr': 'Overcooked',
#   'namespace': 'epic',
#   'orig_price': 1699,
#   'fmt_orig_price': '$16.99',
#   'tags': [{'id': '1216'},
#    {'id': '1264'},
#    {'id': '1393'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1263'}]},
#  {'id': '3f9b7d87d6ea4ac1bb26d49683bd7064',
#   'descr': 'Join Carl and June on what begins as a magical outing to their favorite spot, and try to unlock the sequence of events that could save the day – and June’s life – in this cinematic experience that will compel you  to ask yourself: “What would I do to save the one I love?”  Las...',
#   'namespace': '4fd85a772cd5471aa5e38efcaa0d6f24',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1367'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1263'}]},
#  {'id': '73f7ee3f9e5540ff963573b9c3b08744',
#   'descr': 'Rebel Galaxy is a game of action-packed combat, exploration, discovery, trade, and “negotiation” with the outlandish denizens at the edge of the known universe.  You’ll battle pirates, explore anomalies, befriend aliens, scavenge battle wreckage, mine asteroids, and discover a...',
#   'namespace': 'weaver',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1281'},
#    {'id': '21138'},
#    {'id': '1188'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1367'},
#    {'id': '1370'},
#    {'id': '1307'},
#    {'id': '9547'},
#    {'id': '21149'},
#    {'id': '9549'},
#    {'id': '21119'}]},
#  {'id': 'e820a1ab24ca4bd2b725ba33194489d4',
#   'descr': 'Bullet, Guns, & Puns',
#   'namespace': 'be13f6c4fb11427fbf3313ce93b97cc0',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1216'},
#    {'id': '21122'},
#    {'id': '21894'},
#    {'id': '21129'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1263'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21109'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '1083'},
#    {'id': '1117'},
#    {'id': '21149'},
#    {'id': '10719'}]},
#  None,
#  {'id': 'b8c9b6788e4b4794b2b537076c2ced9d',
#   'descr': 'City of Brass',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1370'},
#    {'id': '1083'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1294'}]},
#  {'id': '927bf0728077496ea33372e6c52b028a',
#   'descr': 'RiME',
#   'namespace': 'epic',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1298'},
#    {'id': '1381'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '1117'},
#    {'id': '9549'}]},
#  {'id': 'fdf22ba0f79b4cdda26efacdd6da0531',
#   'descr': 'Stories Untold',
#   'namespace': 'epic',
#   'orig_price': 999,
#   'fmt_orig_price': '$9.99',
#   'tags': [{'id': '1395'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '1117'},
#    {'id': '1294'}]},
#  {'id': '5c36e7edaa91442496d9223bccce9e66',
#   'descr': 'World of Goo',
#   'namespace': 'epic',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1298'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '1117'},
#    {'id': '1263'}]},
#  {'id': '0e3a524afe7043c39148c1c3c35dd6c7',
#   'descr': 'Transistor',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1395'},
#    {'id': '1367'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '9549'}]},
#  {'id': 'ea1854d7e3004420ba3f0759384514c6',
#   'descr': 'You wake up, alone, on a strange island full of puzzles.',
#   'namespace': 'magnolia',
#   'orig_price': 3999,
#   'fmt_orig_price': '$39.99',
#   'tags': [{'id': '1298'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '1117'},
#    {'id': '1294'},
#    {'id': '21150'},
#    {'id': '10719'}]},
#  {'id': 'ebf5f23b876944f89d140750e756585d',
#   'descr': 'Choose Your Fate…',
#   'namespace': 'hibiscus',
#   'orig_price': 999,
#   'fmt_orig_price': '$9.99',
#   'tags': [{'id': '1395'},
#    {'id': '21894'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '1117'},
#    {'id': '9549'},
#    {'id': '10719'},
#    {'id': '1263'}]},
#  {'id': 'cd44981c3cea431a9a203ff94b132994',
#   'descr': 'Welcome to the Far, Far Range',
#   'namespace': 'corydalis',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '21122'},
#    {'id': '1188'},
#    {'id': '1381'},
#    {'id': '21130'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '9549'},
#    {'id': '1294'},
#    {'id': '21138'},
#    {'id': '21139'},
#    {'id': '21140'},
#    {'id': '21141'},
#    {'id': '1370'},
#    {'id': '1307'},
#    {'id': '21149'},
#    {'id': '10719'},
#    {'id': '21119'}]},
#  {'id': 'f0b60db562384b70bfe441f1965736d9',
#   'descr': 'A haunted hotel, an abandoned circus, a burnt-out pillow factory, a dead body pixelating under the bridge, toilets that run on vacuum tubes... you’ve never visited a place like this before.',
#   'namespace': 'tulip',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1298'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '1117'},
#    {'id': '9549'},
#    {'id': '21150'},
#    {'id': '10719'},
#    {'id': '1263'}]},
#  {'id': '15a6c7220ba045448aeaed7e7c2f9a1f',
#   'descr': 'Axiom Verge',
#   'namespace': 'epic',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1216'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1247'},
#    {'id': '1151'}]},
#  {'id': 'f2546a46804147bfb6ab74937caf9295',
#   'descr': 'For 1-100 players! Your phones or tablets are your controllers! The team behind YOU DON’T KNOW JACK presents FIVE guffaw-inducing party games in one pack!   Games include:   1) The comedy trivia sensation YOU DON’T NOW JACK 2015 (1-4 players) with hundreds of all-new questions...',
#   'namespace': 'feverfew',
#   'orig_price': 2499,
#   'fmt_orig_price': '$24.99',
#   'tags': [{'id': '1296'},
#    {'id': '1203'},
#    {'id': '1110'},
#    {'id': '1318'},
#    {'id': '9547'},
#    {'id': '10719'}]},
#  {'id': 'b1f4888a7c9b4449b6bfbace4de24a9c',
#   'descr': "What Remains of Edith Finch is a collection of strange tales about a family in Washington state. As Edith, you’ll explore the colossal Finch house, searching for stories as she explores her family history and tries to figure out why she's the last one in her family left alive....",
#   'namespace': 'badger',
#   'orig_price': 1999,
#   'fmt_orig_price': '$19.99',
#   'tags': [{'id': '1298'},
#    {'id': '1395'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1294'}]},
#  {'id': '13434c6d49b742c7b195201573c146c9',
#   'descr': 'Super Meat Boy',
#   'namespace': 'epic',
#   'orig_price': 1499,
#   'fmt_orig_price': '$14.99',
#   'tags': [{'id': '1216'},
#    {'id': '1370'},
#    {'id': '9547'},
#    {'id': '9549'},
#    {'id': '1151'}]},
#  {'id': 'a6d73af1b7de4ae086e61f462a351272',
#   'descr': 'Subnautica',
#   'namespace': 'epic',
#   'orig_price': 2999,
#   'fmt_orig_price': '$29.99',
#   'tags': [{'id': '1080'},
#    {'id': '1370'},
#    {'id': '1307'},
#    {'id': '9547'},
#    {'id': '9548'},
#    {'id': '1117'},
#    {'id': '9549'}]}]

# %%
# worried about data loss (long time to re-run), saving copies two ways to not overwrite by accident
big_df_copy = big_df.copy()
big_df_copy2 = big_df

# %%
# first adding empty rows for all failed "None" games, then converting to dataframe
data = [d if d is not None else {} for d in big_df]
adf = pd.DataFrame(data)

# merging the API and scraped game data, indices should still match
# print(adf.columns, "\n", gdf.columns)
# print(adf.head(5), gdf.head(5))
joined = pd.merge(adf, gdf, left_index = True, right_index = True)
# print(joined.columns)
joined.sample(15)

# saving data to CSV
# adf.to_csv("~/Desktop/dshw/EGS_project/data/df_api.csv", index = True)  # A in adf for "A"pi source
# gdf.to_csv("~/Desktop/dshw/EGS_project/data/df_scraped.csv", index = True)  # G in gdf for "G"ames list source
joined.to_csv("~/Desktop/dshw/EGS_project/data/df_joined.csv", index = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # first adding empty rows for all failed "None" games, then converting to dataframe
# ----> 2 data = [d if d is not None else {} for d in big_df]
#       3 adf = pd.DataFrame(data)
#       5 # merging the API and scraped game data, indices should still match
#       6 # print(adf.columns, "\n", gdf.columns)
#       7 # print(adf.head(5), gdf.head(5))
#
# NameError: name 'big_df' is not defined

# %%
pd.read_csv()
